# %% [markdown]
# #### Analysis the data “BreadBasket_DMS.csv” and suggest which items is : best sellers, high frequent item, and high correlation.

# %% [markdown]
# #### Input any item and suggest some items should by together.

# %%
import pandas as pd
import numpy as np
import apyori
from mlxtend import frequent_patterns
from mlxtend.preprocessing import TransactionEncoder
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data preprocessing for apyori

# %%
# get data
df = pd.read_csv('BreadBasket_DMS.csv')
df.head()
# Out:
#        Date      Time  Transaction           Item
# 0  30-10-16   9:58:11            1          Bread
# 1  30-10-16  10:05:34            2   Scandinavian
# 2  30-10-16  10:05:34            2   Scandinavian
# 3  30-10-16  10:07:57            3  Hot chocolate
# 4  30-10-16  10:07:57            3            Jam

# %%
records = []
for i in range(df.shape[0]):
    records.append([df.values[i, j] for j in range(2, 4)])
records
# Out:
# [[1, 'Bread'],
#  [2, 'Scandinavian'],
#  [2, 'Scandinavian'],
#  [3, 'Hot chocolate'],
#  [3, 'Jam'],
#  [3, 'Cookies'],
#  [4, 'Muffin'],
#  [5, 'Coffee'],
#  [5, 'Pastry'],
#  [5, 'Bread'],
#  [6, 'Medialuna'],
#  [6, 'Pastry'],
#  [6, 'Muffin'],
#  [7, 'Medialuna'],
#  [7, 'Pastry'],
#  [7, 'Coffee'],
#  [7, 'Tea'],
#  [8, 'Pastry'],
#  [8, 'Bread'],
#  [9, 'Bread'],
#  [9, 'Muffin'],
#  [10, 'Scandinavian'],
#  [10, 'Medialuna'],
#  [11, 'Bread'],
#  [11, 'Medialuna'],
#  [11, 'Bread'],
#  [11, 'NONE'],
#  [12, 'Jam'],
#  [12, 'Coffee'],
#  [12, 'Tartine'],
#  [12, 'Pastry'],
#  [12, 'Tea'],
#  [13, 'Basket'],
#  [13, 'Bread'],
#  [13, 'Coffee'],
#  [14, 'Bread'],
#  [14, 'Medialuna'],
#  [14, 'Pastry'],
#  [15, 'NONE'],
#  [15, 'NONE'],
#  [15, 'Mineral water'],
#  [15, 'Scandinavian'],
#  [16, 'Bread'],
#  [16, 'Medialuna'],
#  [16, 'Coffee'],
#  [17, 'Hot chocolate'],
#  [18, 'Farm House'],
#  [19, 'Farm House'],
#  [19, 'Bread'],
#  [20, 'Bread'],
#  [20, 'Medialuna'],
#  [21, 'Coffee'],
#  [21, 'Coffee'],
#  [21, 'Medialuna'],
#  [21, 'Bread'],
#  [22, 'Jam'],
#  [23, 'Scandinavian'],
#  [23, 'Muffin'],
#  [24, 'Bread'],
#  [25, 'Scandinavian'],
#  [26, 'Fudge'],
#  [27, 'Scandinavian'],
#  [28, 'Coffee'],
#  [28, 'Bread'],
#  [29, 'Bread'],
#  [29, 'Jam'],
#  [29, 'NONE'],
#  [30, 'Bread'],
#  [31, 'Basket'],
#  [32, 'Scandinavian'],
#  [32, 'Muffin'],
#  [33, 'Coffee'],
#  [34, 'Coffee'],
#  [34, 'Muffin'],
#  [35, 'Muffin'],
#  [35, 'Scandinavian'],
#  [36, 'Tea'],
#  [36, 'Bread'],
#  [37, 'Coffee'],
#  [37, 'Bread'],
#  [37, 'NONE'],
#  [38, 'Bread'],
#  [38, 'Tea'],
#  [39, 'Scandinavian'],
#  [40, 'Juice'],
#  [40, 'NONE'],
#  [40, 'Tartine'],
#  [40, 'Coffee'],
#  [40, 'Muffin'],
#  [41, 'Scandinavian'],
#  [42, 'Bread'],
#  [42, 'Tea'],
#  [43, 'Scandinavian'],
#  [43, 'Fudge'],
#  [44, 'Coffee'],
#  [44, 'Medialuna'],
#  [45, 'Coffee'],
#  [45, 'Hot chocolate'],
#  [45, 'Medialuna'],
#  [46, 'Coffee'],
#  [47, "Ella's Kitchen Pouches"],
#  [47, 'Juice'],
#  [47, 'Bread'],
#  [47, 'Muffin'],
#  [47, 'Jam'],
#  [48, 'Coffee'],
#  [49, 'Coffee'],
#  [49, 'Coffee'],
#  [49, 'Medialuna'],
#  [50, 'Bread'],
#  [50, 'Victorian Sponge'],
#  [51, 'Bread'],
#  [52, 'Scandinavian'],
#  [54, 'Bread'],
#  [55, 'Frittata'],
#  [55, 'Coffee'],
#  [55, 'Tea'],
#  [55, 'Hearty & Seasonal'],
#  [56, 'Coffee'],
#  [56, 'Frittata'],
#  [57, 'Scandinavian'],
#  [58, 'Victorian Sponge'],
#  [58, 'Hot chocolate'],
#  [58, 'Tea'],
#  [58, 'Soup'],
#  [59, 'Tea'],
#  [59, 'NONE'],
#  [60, 'Cookies'],
#  [60, 'Coffee'],
#  [60, 'Juice'],
#  [60, 'Coffee'],
#  [61, 'Coffee'],
#  [62, 'Pick and Mix Bowls'],
#  [62, 'Hearty & Seasonal'],
#  [62, 'Hearty & Seasonal'],
#  [62, 'Coffee'],
#  [62, 'Smoothies'],
#  [62, 'Coffee'],
#  [63, 'Coffee'],
#  [64, 'Cake'],
#  [65, 'NONE'],
#  [65, 'Tartine'],
#  [65, 'Mighty Protein'],
#  [65, 'Tea'],
#  [65, 'Coffee'],
#  [66, 'Hearty & Seasonal'],
#  [66, 'Frittata'],
#  [66, 'Mineral water'],
#  [67, 'Hearty & Seasonal'],
#  [67, 'NONE'],
#  [67, 'Mineral water'],
#  [67, 'Muffin'],
#  [68, 'Frittata'],
#  [68, 'Coffee'],
#  [68, 'Tea'],
#  [68, 'Scandinavian'],
#  [68, 'Chicken sand'],
#  [69, 'Bread'],
#  [69, 'Tea'],
#  [69, 'Victorian Sponge'],
#  [70, 'Fudge'],
#  [71, 'Muffin'],
#  [72, 'Coffee'],
#  [72, 'Bread'],
#  [73, 'Bread'],
#  [74, 'Coffee'],
#  [74, 'Bread'],
#  [75, 'NONE'],
#  [75, 'Jam'],
#  [75, 'Frittata'],
#  [76, 'Coffee'],
#  [77, 'Scandinavian'],
#  [78, 'Fudge'],
#  [79, 'Fudge'],
#  [79, 'Tea'],
#  [79, 'Coffee'],
#  [79, 'Muffin'],
#  [80, 'Frittata'],
#  [80, 'Bread'],
#  [80, 'Coffee'],
#  [81, 'Coffee'],
#  [81, 'Cake'],
#  [82, 'Tartine'],
#  [82, 'NONE'],
#  [82, 'Bread'],
#  [83, 'Coffee'],
#  [83, 'Bread'],
#  [84, 'Bread'],
#  [85, 'Coffee'],
#  [85, 'Coffee'],
#  [85, 'Pastry'],
#  [85, 'Medialuna'],
#  [86, 'Juice'],
#  [87, 'Bread'],
#  [88, 'Coffee'],
#  [88, 'Coffee'],
#  [88, 'Jam'],
#  [89, 'Bread'],
#  [90, 'Bread'],
#  [90, 'Coffee'],
#  [91, 'Tea'],
#  [91, 'NONE'],
#  [92, 'Coffee'],
#  [93, 'Bread'],
#  [93, 'Coke'],
#  [94, 'Coffee'],
#  [94, 'Coffee'],
#  [95, 'Tea'],
#  [95, 'Pastry'],
#  [95, 'Farm House'],
#  [96, 'Pastry'],
#  [96, 'Pastry'],
#  [96, 'Coffee'],
#  [96, 'Juice'],
#  [97, 'Coffee'],
#  [97, 'Pastry'],
#  [97, 'Juice'],
#  [98, 'Farm House'],
#  [99, 'Pastry'],
#  [99, 'Pastry'],
#  [99, 'Coffee'],
#  [99, 'Bread'],
#  [100, 'Bread'],
#  [101, 'Coffee'],
#  [101, 'Pastry'],
#  [102, 'Farm House'],
#  [103, 'NONE'],
#  [103, 'Bread'],
#  [104, 'Coffee'],
#  [104, 'Coffee'],
#  [104, 'Medialuna'],
#  [104, 'Muffin'],
#  [104, 'Coffee'],
#  [105, 'Coffee'],
#  [105, 'Tea'],
#  [105, 'NONE'],
#  [105, 'Cake'],
#  [106, 'Coffee'],
#  [106, 'Coffee'],
#  [106, 'Pastry'],
#  [106, 'Pastry'],
#  [107, 'Coffee'],
#  [107, 'Tea'],
#  [108, 'Farm House'],
#  [108, 'Muffin'],
#  [109, 'Bread'],
#  [109, 'Muffin'],
#  [109, 'Pastry'],
#  [110, 'Pastry'],
#  [111, 'Coffee'],
#  [112, 'Coffee'],
#  [113, 'Coffee'],
#  [113, 'Cake'],
#  [114, 'Farm House'],
#  [115, 'Bread'],
#  [116, 'Coffee'],
#  [117, 'Cookies'],
#  [117, 'Cake'],
#  [117, 'Coffee'],
#  [117, 'My-5 Fruit Shoot'],
#  [118, 'Cookies'],
#  [118, 'Cookies'],
#  [118, 'Tea'],
#  [118, 'Pastry'],
#  [119, 'Coffee'],
#  [119, 'Coffee'],
#  [119, 'Muffin'],
#  [120, 'Farm House'],
#  [121, 'Coffee'],
#  [121, 'Bread'],
#  [122, 'Cookies'],
#  [123, 'Jam'],
#  [123, 'NONE'],
#  [123, 'Coffee'],
#  [123, 'Coffee'],
#  [123, 'Juice'],
#  [124, 'Coffee'],
#  [124, 'Soup'],
#  [125, 'Tea'],
#  [126, 'Coffee'],
#  [126, 'Jam'],
#  [127, 'Farm House'],
#  [128, 'NONE'],
#  [128, 'Tartine'],
#  [128, 'Coffee'],
#  [128, 'Tea'],
#  [129, 'Coffee'],
#  [129, 'Coffee'],
#  [129, 'Cake'],
#  [130, 'Coffee'],
#  [130, 'Coffee'],
#  [130, 'Muffin'],
#  [131, 'Bread'],
#  [131, 'Coffee'],
#  [132, 'Tea'],
#  [132, 'Juice'],
#  [132, 'Pick and Mix Bowls'],
#  [132, 'Cookies'],
#  [133, 'Hearty & Seasonal'],
#  [133, 'Soup'],
#  [134, 'Hearty & Seasonal'],
#  [134, 'Tea'],
#  [134, 'Farm House'],
#  [135, 'Bread'],
#  [136, 'Tea'],
#  [136, 'Soup'],
#  [137, 'Farm House'],
#  [138, 'Soup'],
#  [138, 'Hearty & Seasonal'],
#  [138, 'Coffee'],
#  [139, 'Bread'],
#  [139, 'Muffin'],
#  [139, 'Hearty & Seasonal'],
#  [140, 'Coffee'],
#  [140, 'Coffee'],
#  [140, 'Cookies'],
#  [141, 'Bread'],
#  [142, 'Tea'],
#  [142, 'Muffin'],
#  [143, 'Tea'],
#  [144, 'Soup'],
#  [144, 'Hearty & Seasonal'],
#  [145, 'Coffee'],
#  [145, 'Tea'],
#  [145, 'Focaccia'],
#  [146, 'Sandwich'],
#  [147, 'Tartine'],
#  [147, 'Coffee'],
#  [148, 'Fudge'],
#  [148, 'Coffee'],
#  [148, 'Coffee'],
#  [149, 'Coffee'],
#  [150, 'Bread'],
#  [151, 'Coke'],
#  [151, 'Soup'],
#  [152, 'Muffin'],
#  [153, 'Tea'],
#  [153, 'Coffee'],
#  [153, 'Cookies'],
#  [153, 'Muffin'],
#  [154, 'Mighty Protein'],
#  [154, 'Hearty & Seasonal'],
#  [154, 'Coffee'],
#  [154, 'Coke'],
#  [155, 'Tea'],
#  [155, 'Muffin'],
#  [155, 'Sandwich'],
#  [156, 'Coffee'],
#  [156, 'Muffin'],
#  [157, 'Coffee'],
#  [157, 'Bread'],
#  [158, 'Coffee'],
#  [158, 'Muffin'],
#  [159, 'Bread'],
#  [159, 'Hot chocolate'],
#  [159, 'Cookies'],
#  [160, 'Mineral water'],
#  [160, 'Muffin'],
#  [161, 'Tea'],
#  [162, 'Muffin'],
#  [163, 'Coffee'],
#  [163, 'Juice'],
#  [164, 'Coffee'],
#  [164, 'Muffin'],
#  [165, 'Tea'],
#  [166, 'Coffee'],
#  [166, 'Muffin'],
#  [167, 'Sandwich'],
#  [167, 'Hearty & Seasonal'],
#  [167, 'Bread'],
#  [167, 'Mineral water'],
#  [168, 'Tea'],
#  [168, 'Coffee'],
#  [169, 'Mineral water'],
#  [170, 'Coffee'],
#  [171, 'Soup'],
#  [171, 'Tea'],
#  [172, 'Bread'],
#  [172, 'Coffee'],
#  [173, 'Bread'],
#  [173, 'Muffin'],
#  [174, 'Coffee'],
#  [175, 'Bread'],
#  [176, 'Cookies'],
#  [176, 'Coffee'],
#  [178, 'Coffee'],
#  [178, 'Pastry'],
#  [179, 'Coffee'],
#  [179, 'Pastry'],
#  [180, 'Jam'],
#  [180, 'Tea'],
#  [181, 'Tea'],
#  [181, 'Tea'],
#  [182, 'Pastry'],
#  [182, 'Pastry'],
#  [182, "Ella's Kitchen Pouches"],
#  [183, 'Pastry'],
#  [184, 'Farm House'],
#  [184, 'NONE'],
#  [184, 'Tea'],
#  [185, 'Tea'],
#  [185, 'Victorian Sponge'],
#  [186, 'Tea'],
#  [186, 'Pastry'],
#  [187, 'Bread'],
#  [188, 'Coffee'],
#  [189, 'Bread'],
#  [189, 'Coffee'],
#  [190, 'Coffee'],
#  [190, 'Pastry'],
#  [190, 'Pastry'],
#  [191, 'Soup'],
#  [191, 'Tea'],
#  [192, 'NONE'],
#  [192, 'Bread'],
#  [193, 'Coffee'],
#  [194, 'Bread'],
#  [194, 'Bread'],
#  [195, 'Bread'],
#  [195, 'NONE'],
#  [195, 'Scandinavian'],
#  [196, 'Bread'],
#  [196, 'Cake'],
#  [196, 'Cookies'],
#  [197, 'Coffee'],
#  [197, 'Coffee'],
#  [197, 'Tea'],
#  [198, 'Coffee'],
#  [198, 'Cookies'],
#  [199, 'Coffee'],
#  [200, 'Bread'],
#  [201, 'NONE'],
#  [201, 'Coffee'],
#  [201, 'Pastry'],
#  [202, 'Coffee'],
#  [202, 'Coffee'],
#  [203, 'Coffee'],
#  [204, 'Scandinavian'],
#  [204, 'Bread'],
#  [205, 'Coffee'],
#  [205, 'Coffee'],
#  [205, 'Pastry'],
#  [206, 'Scandinavian'],
#  [206, 'Coffee'],
#  [206, 'Pastry'],
#  [207, 'Hearty & Seasonal'],
#  [207, 'Coffee'],
#  [207, 'Muffin'],
#  [208, 'Bread'],
#  [209, 'Coffee'],
#  [210, 'Scandinavian'],
#  [211, 'Soup'],
#  [211, 'Coffee'],
#  [212, 'Coffee'],
#  [212, 'Cookies'],
#  [212, 'Tartine'],
#  [213, 'Bread'],
#  [214, 'Bread'],
#  [214, 'Tea'],
#  [214, 'Tea'],
#  [215, 'Pastry'],
#  [215, 'Coffee'],
#  [216, 'Tartine'],
#  [216, 'Coffee'],
#  [217, 'Bread'],
#  [217, 'Cookies'],
#  [218, 'Sandwich'],
#  [219, 'Tartine'],
#  [220, 'Bread'],
#  [220, 'Pastry'],
#  [221, 'Bread'],
#  [221, 'Scandinavian'],
#  [222, 'Scandinavian'],
#  [223, 'Alfajores'],
#  [223, 'Coffee'],
#  [224, 'Coffee'],
#  [225, 'Coffee'],
#  [225, 'Coke'],
#  [225, 'Soup'],
#  [226, 'Cake'],
#  [227, 'Tea'],
#  [227, 'Sandwich'],
#  [227, 'Soup'],
#  [228, 'Coffee'],
#  [229, 'Hearty & Seasonal'],
#  [229, 'Bread'],
#  [230, 'Alfajores'],
#  [231, 'Cake'],
#  [232, 'Tea'],
#  [232, 'Tea'],
#  [232, 'Bread'],
#  [233, 'Coffee'],
#  [233, 'Tea'],
#  [233, 'Bread'],
#  [233, 'Soup'],
#  [234, 'Coffee'],
#  [234, 'Coffee'],
#  [235, 'Scandinavian'],
#  [236, 'Fudge'],
#  [237, 'Coffee'],
#  [237, 'Sandwich'],
#  [238, 'Tea'],
#  [238, 'Bread'],
#  [238, 'Cookies'],
#  [238, 'Pastry'],
#  [239, 'Muffin'],
#  [240, 'Scandinavian'],
#  [241, 'Jam'],
#  [241, 'Tea'],
#  [242, 'Juice'],
#  [242, 'Tea'],
#  [242, 'Alfajores'],
#  [243, 'Cake'],
#  [243, 'Muffin'],
#  [243, 'Coffee'],
#  [243, 'Soup'],
#  [244, 'Hot chocolate'],
#  [244, 'Cake'],
#  [244, 'Coffee'],
#  [245, 'Cake'],
#  [245, 'Cookies'],
#  [246, 'Tea'],
#  [246, 'Bread'],
#  [247, 'Alfajores'],
#  [247, 'Coffee'],
#  [247, 'Coffee'],
#  [247, 'Coffee'],
#  [247, 'Juice'],
#  [248, 'Coffee'],
#  [248, 'Tea'],
#  [248, 'Soup'],
#  [249, 'Hot chocolate'],
#  [250, 'Cookies'],
#  [251, 'Coffee'],
#  [251, 'Medialuna'],
#  [252, 'Bread'],
#  [252, 'Eggs'],
#  [253, 'Scandinavian'],
#  [254, 'Medialuna'],
#  [255, 'Coffee'],
#  [255, 'Coffee'],
#  [255, 'Pastry'],
#  [256, 'Coffee'],
#  [256, 'Bread'],
#  [257, 'Bread'],
#  [257, 'Coffee'],
#  [257, 'Pastry'],
#  [257, 'NONE'],
#  [258, 'Coffee'],
#  [258, 'Pastry'],
#  [259, 'Pastry'],
#  [260, 'Coffee'],
#  [261, 'Coffee'],
#  [262, 'Coffee'],
#  [262, 'Hot chocolate'],
#  [262, 'Pastry'],
#  [263, 'Coke'],
#  [264, 'Coffee'],
#  [264, 'Jam'],
#  [265, 'Tea'],
#  [266, 'NONE'],
#  [266, 'Bread'],
#  [266, 'Pastry'],
#  [267, 'Coffee'],
#  [267, 'Alfajores'],
#  [267, 'Farm House'],
#  [268, 'Tea'],
#  [268, 'Pastry'],
#  [269, 'Bread'],
#  [270, 'Coffee'],
#  [270, 'Jam'],
#  [271, 'Coffee'],
#  [271, 'Tea'],
#  [271, 'Coffee'],
#  [271, 'Pastry'],
#  [272, 'Farm House'],
#  [274, 'Coffee'],
#  [274, 'NONE'],
#  [274, 'Bread'],
#  [274, 'Pastry'],
#  [275, 'Farm House'],
#  [276, 'Coffee'],
#  [276, 'Coffee'],
#  [276, 'Pastry'],
#  [277, 'Farm House'],
#  [278, 'Coffee'],
#  [278, 'Pastry'],
#  [279, 'NONE'],
#  [279, 'Coffee'],
#  [280, 'Coffee'],
#  [280, 'Pastry'],
#  [281, 'Bread'],
#  [281, 'Bread'],
#  [282, 'Bread'],
#  [282, 'Coffee'],
#  [282, 'Pastry'],
#  [283, 'Pastry'],
#  [283, 'Coffee'],
#  [284, 'Coffee'],
#  [284, 'Farm House'],
#  [285, 'Farm House'],
#  [285, 'Farm House'],
#  [285, 'Pastry'],
#  [286, 'Bread'],
#  [286, 'Juice'],
#  [286, 'Alfajores'],
#  [287, 'Coffee'],
#  [287, 'Pastry'],
#  [288, 'Bread'],
#  [288, 'Alfajores'],
#  [289, 'Bread'],
#  [290, 'Coffee'],
#  [290, 'Cookies'],
#  [291, 'Coffee'],
#  [292, 'Cookies'],
#  [293, 'Hearty & Seasonal'],
#  [294, 'Coffee'],
#  [295, 'Jam'],
#  [295, 'Tartine'],
#  [295, 'Bread'],
#  [296, 'Farm House'],
#  [296, 'Scandinavian'],
#  [297, 'Hearty & Seasonal'],
#  [297, 'Coffee'],
#  [297, 'Muffin'],
#  [297, 'Scandinavian'],
#  [298, 'Tartine'],
#  [298, 'Pick and Mix Bowls'],
#  [298, 'NONE'],
#  [298, 'Coffee'],
#  [298, 'Coke'],
#  [299, 'Bread'],
#  [300, 'Scandinavian'],
#  [300, 'Farm House'],
#  [300, 'Alfajores'],
#  [300, 'Coffee'],
#  [300, 'Coffee'],
#  [301, 'Juice'],
#  [301, 'Mineral water'],
#  [301, 'Soup'],
#  [302, 'Soup'],
#  [302, 'Tea'],
#  [303, 'Juice'],
#  [303, 'Tea'],
#  [303, 'Cookies'],
#  [303, 'Soup'],
#  [304, 'Hearty & Seasonal'],
#  [304, 'Tea'],
#  [305, 'Fudge'],
#  [306, 'Coffee'],
#  [306, 'Mineral water'],
#  [306, 'Juice'],
#  [306, 'Soup'],
#  [307, 'Hearty & Seasonal'],
#  [308, 'Hearty & Seasonal'],
#  [308, 'Smoothies'],
#  [309, 'Hearty & Seasonal'],
#  [309, 'Tea'],
#  [310, 'Coffee'],
#  [310, 'Sandwich'],
#  [310, 'Sandwich'],
#  [311, 'Cookies'],
#  [311, 'Farm House'],
#  [312, 'Soup'],
#  [312, 'Tea'],
#  [312, 'Juice'],
#  [313, 'Soup'],
#  [314, 'Coffee'],
#  [316, 'Bread'],
#  [317, 'Cookies'],
#  [317, 'Tea'],
#  [318, 'Soup'],
#  [318, 'Hearty & Seasonal'],
#  [318, 'Bread'],
#  [319, 'Coffee'],
#  [320, 'Coffee'],
#  [321, 'Coffee'],
#  [321, 'Tea'],
#  [322, 'Bread'],
#  [323, 'Tea'],
#  [324, 'Coffee'],
#  [324, 'Tea'],
#  [325, 'Coffee'],
#  [326, 'Fudge'],
#  [327, 'Tea'],
#  [328, 'Soup'],
#  [328, 'Tea'],
#  [329, 'Juice'],
#  [330, 'Alfajores'],
#  [331, 'Bread'],
#  [332, 'Coffee'],
#  [332, 'Alfajores'],
#  [333, 'Juice'],
#  [333, 'Alfajores'],
#  [333, 'Cookies'],
#  [333, 'Pick and Mix Bowls'],
#  [333, 'Mineral water'],
#  [334, 'Coffee'],
#  [334, 'Alfajores'],
#  [335, 'Fudge'],
#  [336, 'Mighty Protein'],
#  [336, 'Juice'],
#  [337, 'Coffee'],
#  [337, 'Mineral water'],
#  [337, 'Alfajores'],
#  [338, 'Mighty Protein'],
#  [338, 'Coffee'],
#  [339, 'Alfajores'],
#  [340, 'Coffee'],
#  [340, 'Bread'],
#  [341, 'Medialuna'],
#  [341, 'Medialuna'],
#  [342, 'Medialuna'],
#  [342, 'Bread'],
#  [343, 'Farm House'],
#  [344, 'Coffee'],
#  [344, 'Pastry'],
#  [345, 'Farm House'],
#  [346, 'NONE'],
#  [346, 'Coffee'],
#  [346, 'Coffee'],
#  [346, 'Pastry'],
#  [346, 'Pastry'],
#  [346, 'Coffee'],
#  [347, 'Medialuna'],
#  [348, 'Bread'],
#  [348, 'NONE'],
#  [348, 'Tea'],
#  [348, 'Sandwich'],
#  [349, 'Bread'],
#  [350, 'Jam'],
#  [350, 'Coffee'],
#  [350, 'Farm House'],
#  [351, 'Focaccia'],
#  [352, 'Bread'],
#  [353, 'Tartine'],
#  [353, 'Pastry'],
#  [353, 'Bread'],
#  [353, 'My-5 Fruit Shoot'],
#  [354, 'Farm House'],
#  [354, 'Pastry'],
#  [355, 'Bread'],
#  [355, 'Pastry'],
#  [356, 'Pastry'],
#  [356, 'Bread'],
#  [357, 'Jam'],
#  [357, 'Coffee'],
#  [358, 'Farm House'],
#  [359, 'Bread'],
#  [359, 'Pastry'],
#  [360, 'Coffee'],
#  [360, 'Tea'],
#  [360, 'Bread'],
#  [361, 'Jam'],
#  [363, 'Pastry'],
#  [363, 'Medialuna'],
#  [363, 'Medialuna'],
#  [364, 'Coffee'],
#  [365, 'Tea'],
#  [366, 'Bread'],
#  [367, 'Bread'],
#  [367, 'Pastry'],
#  [368, 'Pastry'],
#  [369, 'Farm House'],
#  [370, 'Tea'],
#  [371, 'Coffee'],
#  [371, 'Brownie'],
#  [371, 'Alfajores'],
#  [371, 'Fudge'],
#  [372, 'Bread'],
#  [372, 'Fudge'],
#  [372, 'Cookies'],
#  [373, 'Coffee'],
#  [374, 'Bread'],
#  [375, 'Coffee'],
#  [375, 'Coffee'],
#  [375, 'Jam'],
#  [375, 'Pastry'],
#  [376, 'Soup'],
#  [376, 'Coffee'],
#  [377, 'Smoothies'],
#  [377, 'Soup'],
#  [377, 'Hearty & Seasonal'],
#  [377, 'Pastry'],
#  [378, 'Pastry'],
#  [378, 'Bread'],
#  [379, 'Pastry'],
#  [379, 'Medialuna'],
#  [380, 'NONE'],
#  [380, 'Tea'],
#  [380, 'Coffee'],
#  [381, 'Bread'],
#  [381, 'Cookies'],
#  [382, 'Coffee'],
#  [382, 'Coffee'],
#  [382, 'Bread'],
#  [382, 'Hearty & Seasonal'],
#  [382, 'Pick and Mix Bowls'],
#  [382, 'Sandwich'],
#  [382, 'Focaccia'],
#  [383, 'Coffee'],
#  [384, 'Coffee'],
#  [384, 'Sandwich'],
#  [384, 'Brownie'],
#  [385, 'Brownie'],
#  [385, 'Cookies'],
#  [386, 'Coffee'],
#  [387, 'Coffee'],
#  [387, 'NONE'],
#  [388, 'Sandwich'],
#  [388, 'NONE'],
#  [388, 'Bread'],
#  [388, 'Coffee'],
#  [389, 'Coffee'],
#  [389, 'Hot chocolate'],
#  [390, 'Tea'],
#  [390, 'NONE'],
#  [391, 'Sandwich'],
#  [391, 'Coffee'],
#  [391, 'Brownie'],
#  [392, 'Brownie'],
#  [392, 'Pastry'],
#  [392, 'Focaccia'],
#  [392, 'Farm House'],
#  [393, 'Cake'],
#  [393, 'Focaccia'],
#  [394, 'Soup'],
#  [394, 'Hearty & Seasonal'],
#  [394, 'Mineral water'],
#  [395, 'Hearty & Seasonal'],
#  [396, 'Hearty & Seasonal'],
#  [397, 'Coffee'],
#  [397, 'Coffee'],
#  [397, 'Pastry'],
#  [398, 'Coffee'],
#  [399, 'Tea'],
#  [399, 'Cake'],
#  [400, 'Coffee'],
#  [400, 'Soup'],
#  [401, 'Bread'],
#  [401, 'Focaccia'],
#  [401, 'Fudge'],
#  [402, 'Hot chocolate'],
#  [402, 'Coffee'],
#  [402, 'Alfajores'],
#  [403, 'Brownie'],
#  [403, 'Pastry'],
#  [403, 'Cake'],
#  [404, 'Medialuna'],
#  [404, 'Alfajores'],
#  [404, 'Dulce de Leche'],
#  [405, 'Dulce de Leche'],
#  [405, 'Alfajores'],
#  [406, 'Bread'],
#  [406, 'Cake'],
#  [407, 'Cake'],
#  [407, 'Coffee'],
#  [408, 'Bread'],
#  [409, 'Sandwich'],
#  [410, 'Bread'],
#  [410, 'Coffee'],
#  [410, 'Alfajores'],
#  [410, 'Medialuna'],
#  [411, 'Coffee'],
#  [412, 'Bread'],
#  [412, 'Alfajores'],
#  [413, 'Tea'],
#  [413, 'Coffee'],
#  [414, 'Bread'],
#  [415, 'Dulce de Leche'],
#  [416, 'Farm House'],
#  [417, 'Fudge'],
#  [418, 'Coffee'],
#  [419, 'Coffee'],
#  [419, 'Alfajores'],
#  [419, 'Juice'],
#  [419, "Ella's Kitchen Pouches"],
#  [419, 'Brownie'],
#  [420, 'Alfajores'],
#  [421, 'Alfajores'],
#  [421, 'Brownie'],
#  [421, 'Cookies'],
#  [421, 'Bread'],
#  [421, 'Juice'],
#  [422, 'Cake'],
#  [422, 'Cookies'],
#  [423, 'Pick and Mix Bowls'],
#  [424, 'Coffee'],
#  [425, 'Farm House'],
#  [426, 'Tea'],
#  [427, 'Coffee'],
#  [428, 'Focaccia'],
#  [428, 'Farm House'],
#  [429, 'Dulce de Leche'],
#  [430, 'Juice'],
#  [430, 'My-5 Fruit Shoot'],
#  [430, "Ella's Kitchen Pouches"],
#  [430, 'Cookies'],
#  [431, 'Bread'],
#  [432, 'Hot chocolate'],
#  [433, 'Coffee'],
#  [435, 'Coffee'],
#  [436, 'Coffee'],
#  [437, 'Medialuna'],
#  [438, 'Bread'],
#  [438, 'Tea'],
#  [438, 'Jam'],
#  [439, 'Farm House'],
#  [440, 'Bread'],
#  [441, 'Coffee'],
#  [441, 'NONE'],
#  [442, 'Medialuna'],
#  [442, 'Coffee'],
#  [443, 'Bread'],
#  [444, 'Medialuna'],
#  [444, 'Pastry'],
#  [444, 'Medialuna'],
#  [445, 'Coffee'],
#  [445, 'Coffee'],
#  [445, 'Jam'],
#  [446, 'Bread'],
#  [446, 'Coffee'],
#  [447, 'Coffee'],
#  [447, 'Coffee'],
#  [448, 'Bread'],
#  [449, 'Hot chocolate'],
#  [450, 'Bread'],
#  [450, 'Medialuna'],
#  [451, 'Bread'],
#  [451, 'Jam'],
#  [452, 'Jam'],
#  [452, 'Bread'],
#  [453, 'Coffee'],
#  [453, 'Bread'],
#  [454, 'Bread'],
#  [454, 'Farm House'],
#  [455, 'Bread'],
#  [455, 'Coffee'],
#  [455, 'Coffee'],
#  [456, 'Tea'],
#  [456, 'Pastry'],
#  [457, 'Coffee'],
#  [457, 'Coffee'],
#  [458, 'Bread'],
#  [459, 'Pastry'],
#  [459, 'Brownie'],
#  [460, 'Farm House'],
#  [461, 'Coffee'],
#  [462, 'Tea'],
#  [462, 'Coffee'],
#  [462, 'Honey'],
#  [462, 'Cookies'],
#  [463, 'Tea'],
#  [464, 'Bread'],
#  [465, 'Brownie'],
#  [466, 'Bread'],
#  [466, 'Coffee'],
#  [467, 'Bread'],
#  [468, 'Coffee'],
#  [469, 'Tea'],
#  [469, 'Tea'],
#  [470, 'Tea'],
#  [471, 'Coffee'],
#  [471, 'Coffee'],
#  [473, 'Bread'],
#  [473, 'Coffee'],
#  [474, 'Bread'],
#  [474, 'Bread'],
#  [475, 'Bread'],
#  [475, 'The BART'],
#  [476, 'Coffee'],
#  [476, 'NONE'],
#  [476, 'Brownie'],
#  [477, 'Coffee'],
#  [478, 'Coffee'],
#  [478, 'Brownie'],
#  [479, 'Mineral water'],
#  [479, 'Coffee'],
#  [479, 'Coffee'],
#  [479, 'Tartine'],
#  [479, 'NONE'],
#  [480, 'Brownie'],
#  [480, 'Coffee'],
#  [481, 'Brownie'],
#  [481, 'Juice'],
#  [482, 'Coffee'],
#  [482, 'Coffee'],
#  [482, 'Bread'],
#  [482, 'Tea'],
#  [482, 'Alfajores'],
#  [482, 'Medialuna'],
#  [482, 'Pastry'],
#  [482, 'Jam'],
#  [483, 'Bread'],
#  [484, 'Fudge'],
#  [484, 'Fudge'],
#  [485, 'Coffee'],
#  [485, 'Pick and Mix Bowls'],
#  [486, 'Pastry'],
#  [486, 'Bread'],
#  ...]

# %%
# create a list of transactions
records.sort(key=lambda x: x[0])

transactions = []
for i in range(len(records)):
    if i == 0 or records[i][0] != records[i-1][0]:
        transactions.append([records[i][1]])
    else:
        transactions[-1].append(records[i][1])

transactions
# Out:
# [['Bread'],
#  ['Scandinavian', 'Scandinavian'],
#  ['Hot chocolate', 'Jam', 'Cookies'],
#  ['Muffin'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Medialuna', 'Pastry', 'Muffin'],
#  ['Medialuna', 'Pastry', 'Coffee', 'Tea'],
#  ['Pastry', 'Bread'],
#  ['Bread', 'Muffin'],
#  ['Scandinavian', 'Medialuna'],
#  ['Bread', 'Medialuna', 'Bread', 'NONE'],
#  ['Jam', 'Coffee', 'Tartine', 'Pastry', 'Tea'],
#  ['Basket', 'Bread', 'Coffee'],
#  ['Bread', 'Medialuna', 'Pastry'],
#  ['NONE', 'NONE', 'Mineral water', 'Scandinavian'],
#  ['Bread', 'Medialuna', 'Coffee'],
#  ['Hot chocolate'],
#  ['Farm House'],
#  ['Farm House', 'Bread'],
#  ['Bread', 'Medialuna'],
#  ['Coffee', 'Coffee', 'Medialuna', 'Bread'],
#  ['Jam'],
#  ['Scandinavian', 'Muffin'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Scandinavian'],
#  ['Coffee', 'Bread'],
#  ['Bread', 'Jam', 'NONE'],
#  ['Bread'],
#  ['Basket'],
#  ['Scandinavian', 'Muffin'],
#  ['Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Muffin', 'Scandinavian'],
#  ['Tea', 'Bread'],
#  ['Coffee', 'Bread', 'NONE'],
#  ['Bread', 'Tea'],
#  ['Scandinavian'],
#  ['Juice', 'NONE', 'Tartine', 'Coffee', 'Muffin'],
#  ['Scandinavian'],
#  ['Bread', 'Tea'],
#  ['Scandinavian', 'Fudge'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee', 'Hot chocolate', 'Medialuna'],
#  ['Coffee'],
#  ["Ella's Kitchen Pouches", 'Juice', 'Bread', 'Muffin', 'Jam'],
#  ['Coffee'],
#  ['Coffee', 'Coffee', 'Medialuna'],
#  ['Bread', 'Victorian Sponge'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Frittata', 'Coffee', 'Tea', 'Hearty & Seasonal'],
#  ['Coffee', 'Frittata'],
#  ['Scandinavian'],
#  ['Victorian Sponge', 'Hot chocolate', 'Tea', 'Soup'],
#  ['Tea', 'NONE'],
#  ['Cookies', 'Coffee', 'Juice', 'Coffee'],
#  ['Coffee'],
#  ['Pick and Mix Bowls',
#   'Hearty & Seasonal',
#   'Hearty & Seasonal',
#   'Coffee',
#   'Smoothies',
#   'Coffee'],
#  ['Coffee'],
#  ['Cake'],
#  ['NONE', 'Tartine', 'Mighty Protein', 'Tea', 'Coffee'],
#  ['Hearty & Seasonal', 'Frittata', 'Mineral water'],
#  ['Hearty & Seasonal', 'NONE', 'Mineral water', 'Muffin'],
#  ['Frittata', 'Coffee', 'Tea', 'Scandinavian', 'Chicken sand'],
#  ['Bread', 'Tea', 'Victorian Sponge'],
#  ['Fudge'],
#  ['Muffin'],
#  ['Coffee', 'Bread'],
#  ['Bread'],
#  ['Coffee', 'Bread'],
#  ['NONE', 'Jam', 'Frittata'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Fudge', 'Tea', 'Coffee', 'Muffin'],
#  ['Frittata', 'Bread', 'Coffee'],
#  ['Coffee', 'Cake'],
#  ['Tartine', 'NONE', 'Bread'],
#  ['Coffee', 'Bread'],
#  ['Bread'],
#  ['Coffee', 'Coffee', 'Pastry', 'Medialuna'],
#  ['Juice'],
#  ['Bread'],
#  ['Coffee', 'Coffee', 'Jam'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'NONE'],
#  ['Coffee'],
#  ['Bread', 'Coke'],
#  ['Coffee', 'Coffee'],
#  ['Tea', 'Pastry', 'Farm House'],
#  ['Pastry', 'Pastry', 'Coffee', 'Juice'],
#  ['Coffee', 'Pastry', 'Juice'],
#  ['Farm House'],
#  ['Pastry', 'Pastry', 'Coffee', 'Bread'],
#  ['Bread'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['NONE', 'Bread'],
#  ['Coffee', 'Coffee', 'Medialuna', 'Muffin', 'Coffee'],
#  ['Coffee', 'Tea', 'NONE', 'Cake'],
#  ['Coffee', 'Coffee', 'Pastry', 'Pastry'],
#  ['Coffee', 'Tea'],
#  ['Farm House', 'Muffin'],
#  ['Bread', 'Muffin', 'Pastry'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Cake'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cookies', 'Cake', 'Coffee', 'My-5 Fruit Shoot'],
#  ['Cookies', 'Cookies', 'Tea', 'Pastry'],
#  ['Coffee', 'Coffee', 'Muffin'],
#  ['Farm House'],
#  ['Coffee', 'Bread'],
#  ['Cookies'],
#  ['Jam', 'NONE', 'Coffee', 'Coffee', 'Juice'],
#  ['Coffee', 'Soup'],
#  ['Tea'],
#  ['Coffee', 'Jam'],
#  ['Farm House'],
#  ['NONE', 'Tartine', 'Coffee', 'Tea'],
#  ['Coffee', 'Coffee', 'Cake'],
#  ['Coffee', 'Coffee', 'Muffin'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Juice', 'Pick and Mix Bowls', 'Cookies'],
#  ['Hearty & Seasonal', 'Soup'],
#  ['Hearty & Seasonal', 'Tea', 'Farm House'],
#  ['Bread'],
#  ['Tea', 'Soup'],
#  ['Farm House'],
#  ['Soup', 'Hearty & Seasonal', 'Coffee'],
#  ['Bread', 'Muffin', 'Hearty & Seasonal'],
#  ['Coffee', 'Coffee', 'Cookies'],
#  ['Bread'],
#  ['Tea', 'Muffin'],
#  ['Tea'],
#  ['Soup', 'Hearty & Seasonal'],
#  ['Coffee', 'Tea', 'Focaccia'],
#  ['Sandwich'],
#  ['Tartine', 'Coffee'],
#  ['Fudge', 'Coffee', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coke', 'Soup'],
#  ['Muffin'],
#  ['Tea', 'Coffee', 'Cookies', 'Muffin'],
#  ['Mighty Protein', 'Hearty & Seasonal', 'Coffee', 'Coke'],
#  ['Tea', 'Muffin', 'Sandwich'],
#  ['Coffee', 'Muffin'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Muffin'],
#  ['Bread', 'Hot chocolate', 'Cookies'],
#  ['Mineral water', 'Muffin'],
#  ['Tea'],
#  ['Muffin'],
#  ['Coffee', 'Juice'],
#  ['Coffee', 'Muffin'],
#  ['Tea'],
#  ['Coffee', 'Muffin'],
#  ['Sandwich', 'Hearty & Seasonal', 'Bread', 'Mineral water'],
#  ['Tea', 'Coffee'],
#  ['Mineral water'],
#  ['Coffee'],
#  ['Soup', 'Tea'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Jam', 'Tea'],
#  ['Tea', 'Tea'],
#  ['Pastry', 'Pastry', "Ella's Kitchen Pouches"],
#  ['Pastry'],
#  ['Farm House', 'NONE', 'Tea'],
#  ['Tea', 'Victorian Sponge'],
#  ['Tea', 'Pastry'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Pastry', 'Pastry'],
#  ['Soup', 'Tea'],
#  ['NONE', 'Bread'],
#  ['Coffee'],
#  ['Bread', 'Bread'],
#  ['Bread', 'NONE', 'Scandinavian'],
#  ['Bread', 'Cake', 'Cookies'],
#  ['Coffee', 'Coffee', 'Tea'],
#  ['Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['NONE', 'Coffee', 'Pastry'],
#  ['Coffee', 'Coffee'],
#  ['Coffee'],
#  ['Scandinavian', 'Bread'],
#  ['Coffee', 'Coffee', 'Pastry'],
#  ['Scandinavian', 'Coffee', 'Pastry'],
#  ['Hearty & Seasonal', 'Coffee', 'Muffin'],
#  ['Bread'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Soup', 'Coffee'],
#  ['Coffee', 'Cookies', 'Tartine'],
#  ['Bread'],
#  ['Bread', 'Tea', 'Tea'],
#  ['Pastry', 'Coffee'],
#  ['Tartine', 'Coffee'],
#  ['Bread', 'Cookies'],
#  ['Sandwich'],
#  ['Tartine'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Scandinavian'],
#  ['Scandinavian'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Coke', 'Soup'],
#  ['Cake'],
#  ['Tea', 'Sandwich', 'Soup'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Alfajores'],
#  ['Cake'],
#  ['Tea', 'Tea', 'Bread'],
#  ['Coffee', 'Tea', 'Bread', 'Soup'],
#  ['Coffee', 'Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Coffee', 'Sandwich'],
#  ['Tea', 'Bread', 'Cookies', 'Pastry'],
#  ['Muffin'],
#  ['Scandinavian'],
#  ['Jam', 'Tea'],
#  ['Juice', 'Tea', 'Alfajores'],
#  ['Cake', 'Muffin', 'Coffee', 'Soup'],
#  ['Hot chocolate', 'Cake', 'Coffee'],
#  ['Cake', 'Cookies'],
#  ['Tea', 'Bread'],
#  ['Alfajores', 'Coffee', 'Coffee', 'Coffee', 'Juice'],
#  ['Coffee', 'Tea', 'Soup'],
#  ['Hot chocolate'],
#  ['Cookies'],
#  ['Coffee', 'Medialuna'],
#  ['Bread', 'Eggs'],
#  ['Scandinavian'],
#  ['Medialuna'],
#  ['Coffee', 'Coffee', 'Pastry'],
#  ['Coffee', 'Bread'],
#  ['Bread', 'Coffee', 'Pastry', 'NONE'],
#  ['Coffee', 'Pastry'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Hot chocolate', 'Pastry'],
#  ['Coke'],
#  ['Coffee', 'Jam'],
#  ['Tea'],
#  ['NONE', 'Bread', 'Pastry'],
#  ['Coffee', 'Alfajores', 'Farm House'],
#  ['Tea', 'Pastry'],
#  ['Bread'],
#  ['Coffee', 'Jam'],
#  ['Coffee', 'Tea', 'Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Coffee', 'NONE', 'Bread', 'Pastry'],
#  ['Farm House'],
#  ['Coffee', 'Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Coffee', 'Pastry'],
#  ['NONE', 'Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Bread', 'Bread'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Pastry', 'Coffee'],
#  ['Coffee', 'Farm House'],
#  ['Farm House', 'Farm House', 'Pastry'],
#  ['Bread', 'Juice', 'Alfajores'],
#  ['Coffee', 'Pastry'],
#  ['Bread', 'Alfajores'],
#  ['Bread'],
#  ['Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Cookies'],
#  ['Hearty & Seasonal'],
#  ['Coffee'],
#  ['Jam', 'Tartine', 'Bread'],
#  ['Farm House', 'Scandinavian'],
#  ['Hearty & Seasonal', 'Coffee', 'Muffin', 'Scandinavian'],
#  ['Tartine', 'Pick and Mix Bowls', 'NONE', 'Coffee', 'Coke'],
#  ['Bread'],
#  ['Scandinavian', 'Farm House', 'Alfajores', 'Coffee', 'Coffee'],
#  ['Juice', 'Mineral water', 'Soup'],
#  ['Soup', 'Tea'],
#  ['Juice', 'Tea', 'Cookies', 'Soup'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Fudge'],
#  ['Coffee', 'Mineral water', 'Juice', 'Soup'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal', 'Smoothies'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Coffee', 'Sandwich', 'Sandwich'],
#  ['Cookies', 'Farm House'],
#  ['Soup', 'Tea', 'Juice'],
#  ['Soup'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Tea'],
#  ['Soup', 'Hearty & Seasonal', 'Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Tea'],
#  ['Coffee', 'Tea'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Tea'],
#  ['Soup', 'Tea'],
#  ['Juice'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Coffee', 'Alfajores'],
#  ['Juice', 'Alfajores', 'Cookies', 'Pick and Mix Bowls', 'Mineral water'],
#  ['Coffee', 'Alfajores'],
#  ['Fudge'],
#  ['Mighty Protein', 'Juice'],
#  ['Coffee', 'Mineral water', 'Alfajores'],
#  ['Mighty Protein', 'Coffee'],
#  ['Alfajores'],
#  ['Coffee', 'Bread'],
#  ['Medialuna', 'Medialuna'],
#  ['Medialuna', 'Bread'],
#  ['Farm House'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['NONE', 'Coffee', 'Coffee', 'Pastry', 'Pastry', 'Coffee'],
#  ['Medialuna'],
#  ['Bread', 'NONE', 'Tea', 'Sandwich'],
#  ['Bread'],
#  ['Jam', 'Coffee', 'Farm House'],
#  ['Focaccia'],
#  ['Bread'],
#  ['Tartine', 'Pastry', 'Bread', 'My-5 Fruit Shoot'],
#  ['Farm House', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Pastry', 'Bread'],
#  ['Jam', 'Coffee'],
#  ['Farm House'],
#  ['Bread', 'Pastry'],
#  ['Coffee', 'Tea', 'Bread'],
#  ['Jam'],
#  ['Pastry', 'Medialuna', 'Medialuna'],
#  ['Coffee'],
#  ['Tea'],
#  ['Bread'],
#  ['Bread', 'Pastry'],
#  ['Pastry'],
#  ['Farm House'],
#  ['Tea'],
#  ['Coffee', 'Brownie', 'Alfajores', 'Fudge'],
#  ['Bread', 'Fudge', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Coffee', 'Jam', 'Pastry'],
#  ['Soup', 'Coffee'],
#  ['Smoothies', 'Soup', 'Hearty & Seasonal', 'Pastry'],
#  ['Pastry', 'Bread'],
#  ['Pastry', 'Medialuna'],
#  ['NONE', 'Tea', 'Coffee'],
#  ['Bread', 'Cookies'],
#  ['Coffee',
#   'Coffee',
#   'Bread',
#   'Hearty & Seasonal',
#   'Pick and Mix Bowls',
#   'Sandwich',
#   'Focaccia'],
#  ['Coffee'],
#  ['Coffee', 'Sandwich', 'Brownie'],
#  ['Brownie', 'Cookies'],
#  ['Coffee'],
#  ['Coffee', 'NONE'],
#  ['Sandwich', 'NONE', 'Bread', 'Coffee'],
#  ['Coffee', 'Hot chocolate'],
#  ['Tea', 'NONE'],
#  ['Sandwich', 'Coffee', 'Brownie'],
#  ['Brownie', 'Pastry', 'Focaccia', 'Farm House'],
#  ['Cake', 'Focaccia'],
#  ['Soup', 'Hearty & Seasonal', 'Mineral water'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal'],
#  ['Coffee', 'Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Tea', 'Cake'],
#  ['Coffee', 'Soup'],
#  ['Bread', 'Focaccia', 'Fudge'],
#  ['Hot chocolate', 'Coffee', 'Alfajores'],
#  ['Brownie', 'Pastry', 'Cake'],
#  ['Medialuna', 'Alfajores', 'Dulce de Leche'],
#  ['Dulce de Leche', 'Alfajores'],
#  ['Bread', 'Cake'],
#  ['Cake', 'Coffee'],
#  ['Bread'],
#  ['Sandwich'],
#  ['Bread', 'Coffee', 'Alfajores', 'Medialuna'],
#  ['Coffee'],
#  ['Bread', 'Alfajores'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Dulce de Leche'],
#  ['Farm House'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Coffee', 'Alfajores', 'Juice', "Ella's Kitchen Pouches", 'Brownie'],
#  ['Alfajores'],
#  ['Alfajores', 'Brownie', 'Cookies', 'Bread', 'Juice'],
#  ['Cake', 'Cookies'],
#  ['Pick and Mix Bowls'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Tea'],
#  ['Coffee'],
#  ['Focaccia', 'Farm House'],
#  ['Dulce de Leche'],
#  ['Juice', 'My-5 Fruit Shoot', "Ella's Kitchen Pouches", 'Cookies'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Bread', 'Tea', 'Jam'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee', 'NONE'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Pastry', 'Medialuna'],
#  ['Coffee', 'Coffee', 'Jam'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Coffee'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Bread', 'Medialuna'],
#  ['Bread', 'Jam'],
#  ['Jam', 'Bread'],
#  ['Coffee', 'Bread'],
#  ['Bread', 'Farm House'],
#  ['Bread', 'Coffee', 'Coffee'],
#  ['Tea', 'Pastry'],
#  ['Coffee', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Brownie'],
#  ['Farm House'],
#  ['Coffee'],
#  ['Tea', 'Coffee', 'Honey', 'Cookies'],
#  ['Tea'],
#  ['Bread'],
#  ['Brownie'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Tea', 'Tea'],
#  ['Tea'],
#  ['Coffee', 'Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Bread'],
#  ['Bread', 'The BART'],
#  ['Coffee', 'NONE', 'Brownie'],
#  ['Coffee'],
#  ['Coffee', 'Brownie'],
#  ['Mineral water', 'Coffee', 'Coffee', 'Tartine', 'NONE'],
#  ['Brownie', 'Coffee'],
#  ['Brownie', 'Juice'],
#  ['Coffee',
#   'Coffee',
#   'Bread',
#   'Tea',
#   'Alfajores',
#   'Medialuna',
#   'Pastry',
#   'Jam'],
#  ['Bread'],
#  ['Fudge', 'Fudge'],
#  ['Coffee', 'Pick and Mix Bowls'],
#  ['Pastry', 'Bread'],
#  ['Soup', 'Scandinavian', 'Coffee', 'Mineral water'],
#  ['Juice', 'Mineral water', 'Sandwich', 'Pick and Mix Bowls'],
#  ['Bread', 'NONE', 'NONE', 'Pastry', 'Bread'],
#  ['Hearty & Seasonal', 'Hearty & Seasonal', 'Coffee', 'Coffee'],
#  ['Bread', 'Hearty & Seasonal', 'Coffee', 'Mineral water'],
#  ['Coffee', 'Tartine', 'Sandwich', 'Brownie'],
#  ['Coffee', 'Brownie'],
#  ['Alfajores', 'Coffee', 'Tartine'],
#  ['Mighty Protein', 'Coffee'],
#  ['Coffee', 'Hot chocolate'],
#  ['Soup', 'Jam', 'Coffee', 'Coffee'],
#  ['Mineral water', 'Brownie'],
#  ['Scandinavian', 'Coffee'],
#  ['Scandinavian', 'Coffee'],
#  ['Coffee', 'Coffee'],
#  ['Coffee', 'Coffee', 'Hot chocolate', 'Brownie', 'Hearty & Seasonal'],
#  ['Tea', 'Cake'],
#  ['Medialuna'],
#  ['Alfajores', 'Tea', 'Coffee'],
#  ['Coffee', 'Juice', 'Brownie', 'Alfajores'],
#  ['Coffee', 'Sandwich'],
#  ['Bread', 'Soup'],
#  ['Soup', 'Bread'],
#  ['Bread'],
#  ['Tea', 'Brownie', 'Cookies'],
#  ['Coffee', 'Bread', 'Brownie'],
#  ['Brownie'],
#  ['Cookies', 'Bread', 'Jam'],
#  ['Coffee'],
#  ['Tea', 'Brownie', 'Tea'],
#  ['Alfajores', 'Medialuna', 'Scandinavian'],
#  ['Hot chocolate', 'Coffee', 'Alfajores', 'Cookies'],
#  ['Brownie'],
#  ['Fudge'],
#  ['Tea', 'Brownie'],
#  ['Dulce de Leche', 'Fudge'],
#  ['Bread', 'Scandinavian', 'Fudge', 'Granola', 'Pastry', 'Coffee'],
#  ['Bread', 'Fudge'],
#  ['Hot chocolate', 'Coffee', 'NONE', 'Medialuna', 'Medialuna'],
#  ['Bread'],
#  ['Bread', 'Medialuna'],
#  ['Bread', 'Coffee', 'Medialuna', 'Jam'],
#  ['Jam', 'Coffee', 'Brownie'],
#  ['Bread', 'Coffee', 'Jam'],
#  ['Scandinavian'],
#  ['Coffee', 'Cookies'],
#  ['Coffee', 'Coffee', 'Scandinavian'],
#  ['Bread'],
#  ['Bread'],
#  ['NONE', 'Jam', 'Brownie', 'Coffee', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Hot chocolate'],
#  ['Bread'],
#  ['Bread', 'Bread', 'Medialuna'],
#  ['Coffee', 'Hot chocolate', 'Brownie'],
#  ['Scandinavian'],
#  ['NONE', 'Basket', 'Bread'],
#  ['Coffee', 'Bread', 'Brownie'],
#  ['Cake', 'Fudge'],
#  ['Coffee', 'Hot chocolate', 'Coffee', 'Basket'],
#  ['Scandinavian'],
#  ['Scandinavian'],
#  ['Coffee', 'Bread', 'Coffee', 'Cake', 'Medialuna'],
#  ['Coffee', 'Coffee', 'Medialuna'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Brownie'],
#  ['Medialuna', 'Farm House'],
#  ['Bread', 'Medialuna'],
#  ['Brownie', 'Medialuna', 'Hot chocolate', 'Smoothies', 'Coffee'],
#  ['Bread', 'Tea', 'Coffee', 'Brownie', 'Medialuna'],
#  ['Medialuna', 'Medialuna', 'Cookies'],
#  ['Coffee', 'Medialuna'],
#  ['Bread', 'Fudge'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Cookies'],
#  ['Pastry', 'Bread', 'Brownie'],
#  ['Bread', 'Coffee', 'Bread'],
#  ['NONE', 'Coffee', 'Coffee', 'Tea'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['My-5 Fruit Shoot', 'Coffee', 'Brownie'],
#  ['Coffee', 'Fudge'],
#  ['Coffee'],
#  ['Coffee', 'Basket'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Coffee', 'Brownie'],
#  ['Scandinavian', 'Brownie', 'My-5 Fruit Shoot'],
#  ['NONE', 'Tartine', 'Coffee', 'Hot chocolate', 'Brownie'],
#  ['Brownie', 'Bread', 'Hot chocolate'],
#  ['Jam', 'Fudge'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Mighty Protein', 'Hearty & Seasonal', 'Coffee', 'Tea', 'Cake'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Cake', 'Victorian Sponge', 'Scandinavian'],
#  ['Tea', 'Cake'],
#  ['Coffee', 'Coffee'],
#  ['Coffee', 'Coffee'],
#  ['Bread'],
#  ['Frittata'],
#  ['Coffee', 'Coffee', 'My-5 Fruit Shoot', 'Brownie'],
#  ['Focaccia', 'Fairy Doors'],
#  ['NONE', 'Tea', 'Coffee', 'Coffee', 'NONE'],
#  ['Hot chocolate', 'Hearty & Seasonal', 'Pick and Mix Bowls', 'Brownie'],
#  ['Frittata', 'Coffee'],
#  ['Bread', 'Brownie'],
#  ['Frittata'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Farm House'],
#  ['Pick and Mix Bowls', 'Jam', 'Soup', 'Brownie'],
#  ['Hearty & Seasonal', 'Coffee', 'Tea'],
#  ['Bread'],
#  ['Bread', 'Frittata'],
#  ['Scandinavian'],
#  ['NONE', 'Tartine', 'Hot chocolate', 'Coffee'],
#  ['Coffee', 'Mighty Protein'],
#  ['Frittata', 'Coffee'],
#  ['Scandinavian'],
#  ['Hearty & Seasonal', 'Coffee', 'Mineral water'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Hearty & Seasonal', 'Soup', 'Bread', 'Coffee'],
#  ['Brownie', 'Cake', 'Tea'],
#  ['Mighty Protein', 'Coffee'],
#  ['Coffee', 'Tea', 'Brownie', 'Soup'],
#  ['Cake'],
#  ['Hot chocolate', 'Coffee', 'Cake'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Coffee'],
#  ['Frittata', 'Coffee', 'Brownie'],
#  ['Sandwich', 'Frittata', 'Coke', 'Mineral water', 'Brownie'],
#  ['Granola', 'Scandinavian'],
#  ['Coffee', 'Coke', 'Coffee'],
#  ['Tea', 'Tea', 'Brownie', 'Cake'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Brownie'],
#  ['Cake'],
#  ['Tea'],
#  ['Coffee', 'Coffee', 'Coffee', 'Soup', 'Sandwich', 'Cake'],
#  ['Coffee', 'Bread', 'Brownie'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Coffee', 'Bread', 'Brownie'],
#  ['Brownie', 'Coffee'],
#  ['Coffee', 'Soup', 'Brownie'],
#  ['Fudge'],
#  ['Bread', 'Focaccia'],
#  ['Bread', 'Farm House', 'Jam'],
#  ['Hot chocolate', 'Brownie'],
#  ['Hot chocolate'],
#  ['Coffee', 'Brownie'],
#  ['Medialuna', 'Pastry'],
#  ['Bread'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['NONE', 'Coffee', 'Mineral water'],
#  ['Pastry', 'Bread', 'Hot chocolate'],
#  ['Bread'],
#  ['Bread'],
#  ['Jam', 'Coffee', 'Coffee', 'Bread'],
#  ['NONE', 'Coffee', 'Coffee', 'Pastry'],
#  ['NONE', 'Medialuna', 'Coffee', 'Coffee', 'Focaccia', 'Hearty & Seasonal'],
#  ['Bread', 'Farm House', 'Coffee', 'Jam'],
#  ['Farm House'],
#  ['Coffee', 'Tea', 'Pastry', 'Medialuna'],
#  ['Pastry', 'Medialuna', 'Coffee'],
#  ['Coffee', 'Hot chocolate', 'Basket', 'Farm House'],
#  ['Pastry', 'Farm House'],
#  ['Hot chocolate', 'Coffee', 'My-5 Fruit Shoot'],
#  ['Pastry', 'Medialuna', 'Muffin'],
#  ['Farm House'],
#  ['Muffin', 'Pastry', 'Focaccia'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Focaccia'],
#  ['Coffee', 'Hot chocolate', 'Pastry', 'Jam'],
#  ['Bread'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Tea', 'NONE'],
#  ['Hot chocolate', 'Coffee', 'Mineral water'],
#  ['Coffee', 'Coffee'],
#  ['Coffee'],
#  ['NONE', 'Jam', 'Coffee', 'Coffee'],
#  ['Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread'],
#  ['NONE', 'Muffin', 'Hot chocolate', 'Coffee'],
#  ['Muffin', 'Fudge'],
#  ['Bread'],
#  ['Bread'],
#  ['Farm House'],
#  ['Coffee', 'Muffin'],
#  ['Focaccia'],
#  ['Bread', 'Tea'],
#  ['Coffee', 'Hot chocolate'],
#  ['Coffee', 'Tartine', 'Coffee', 'Pick and Mix Bowls', 'Jam'],
#  ['Jam'],
#  ['Tartine'],
#  ['Bread', 'Coffee'],
#  ['Coffee',
#   'Coffee',
#   'Mineral water',
#   'Juice',
#   'Tartine',
#   'Pick and Mix Bowls'],
#  ['Bread', 'Tea', 'Juice'],
#  ['Coffee', 'Coffee', 'Cake'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Cake', 'Brownie', 'Coffee', 'Coffee'],
#  ['Focaccia', 'Coffee'],
#  ['Tea', 'Coffee', 'Muffin'],
#  ['Coffee'],
#  ['Tea', 'Coffee'],
#  ['Hearty & Seasonal', 'Cake', 'Coffee'],
#  ['Bread', 'Tea', 'Cake'],
#  ['Mighty Protein', 'Coffee'],
#  ['Hot chocolate', 'Muffin'],
#  ['Coffee', 'Coffee', 'Soup', 'Mighty Protein'],
#  ['Jam'],
#  ['Coffee', 'Alfajores'],
#  ['Cake', 'Hot chocolate', 'Alfajores'],
#  ['Hot chocolate', 'Tea', 'Muffin'],
#  ['Brownie'],
#  ['Cake', 'Coffee'],
#  ['Victorian Sponge', 'Alfajores', 'Tea'],
#  ['Bread'],
#  ['Tartine', 'Tea', 'Tartine'],
#  ['Mighty Protein', 'Tea'],
#  ['Bread', 'Fudge'],
#  ['Medialuna', 'Tartine', 'Coffee'],
#  ['Pastry', 'Bread'],
#  ['Pastry', 'Bread'],
#  ['Coffee', 'Tea', 'Alfajores', 'Alfajores'],
#  ['Alfajores', 'Alfajores', 'Coffee'],
#  ['Coffee', 'Alfajores'],
#  ['Alfajores', 'Pastry'],
#  ['Alfajores'],
#  ['Pastry', 'Tea', 'Alfajores', 'Hearty & Seasonal'],
#  ['Tea', 'Sandwich'],
#  ['Empanadas', 'Tea'],
#  ['Alfajores', 'Alfajores', 'Tea'],
#  ['Alfajores'],
#  ['Pastry', 'Dulce de Leche'],
#  ['Coffee', 'Pastry'],
#  ['Farm House', 'Coffee'],
#  ['Bread', 'Scandinavian', 'Medialuna'],
#  ['Bread'],
#  ['Pastry', 'Tea', 'Alfajores'],
#  ['Pastry', 'Coffee'],
#  ['Bread', 'Pastry', 'Muffin', 'Farm House'],
#  ['Medialuna', 'Tea'],
#  ['Alfajores'],
#  ['Sandwich', 'Tea'],
#  ['Tea', 'Bread'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Coffee', 'Coffee', 'Muffin', 'Alfajores', 'Empanadas'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Pastry', 'Medialuna', 'Tea'],
#  ['Tea', 'Bread'],
#  ['Muffin'],
#  ['Coffee', 'Muffin'],
#  ['Coffee', 'Bread', 'Pastry', 'Medialuna'],
#  ['Coffee', 'Coffee', 'Muffin'],
#  ['Muffin', 'Hot chocolate', 'Scandinavian', 'Bread'],
#  ['Farm House'],
#  ['Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Coffee', 'Cookies'],
#  ['Coffee', 'Coffee'],
#  ['Muffin'],
#  ['Coffee', 'Tea', 'Keeping It Local'],
#  ['Coffee', 'Medialuna'],
#  ['Bread'],
#  ['Tartine', 'Scandinavian'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Coffee', 'Coke'],
#  ['Coffee', 'Muffin'],
#  ['Coffee', 'Bread', 'Coffee', 'Medialuna', 'Muffin', 'Scandinavian'],
#  ['Bread'],
#  ['Coke'],
#  ['Bread', 'Scandinavian'],
#  ['Coffee'],
#  ['Bread'],
#  ['Scandinavian', 'Bread'],
#  ['Fudge', 'Fudge'],
#  ['Soup', 'Hearty & Seasonal', 'Coffee'],
#  ['Coke'],
#  ['NONE', 'Coffee', 'Cookies', 'Tea'],
#  ['Pastry', 'Tea', 'Coffee'],
#  ['Bread'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee', 'Coffee', 'Muffin', 'Sandwich', 'Soup'],
#  ['Tea', 'Coffee', 'Muffin'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Empanadas', 'Bread', 'Scandinavian'],
#  ['Coffee', 'Tartine'],
#  ['Tea'],
#  ['Scandinavian'],
#  ['Muffin'],
#  ['Scandinavian', 'Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Coffee'],
#  ['Cookies', 'Scandinavian'],
#  ['Coffee', 'Bread', 'Empanadas', 'Medialuna'],
#  ['Coffee', 'Pastry'],
#  ['Bread'],
#  ['Pastry', 'Tea'],
#  ['Coffee', 'Coffee', 'Pastry'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Keeping It Local'],
#  ['Fudge'],
#  ['NONE', 'Tartine', 'Coffee', 'Coffee'],
#  ['Hot chocolate', 'Coffee', 'Pastry', 'Medialuna'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Coffee', 'Medialuna'],
#  ['Coke'],
#  ['Coffee', 'Coffee', 'Alfajores'],
#  ['Muffin'],
#  ['Farm House', 'Brownie', 'Fudge'],
#  ['Coffee', 'Coffee'],
#  ['Tea', 'Muffin', 'Farm House'],
#  ['Coffee', 'Pastry'],
#  ['Pastry', 'Brownie'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Pastry', 'Coffee', 'Juice'],
#  ['Coffee', 'Bread'],
#  ['Tea', 'Coffee'],
#  ['Tea', 'Alfajores'],
#  ['Alfajores', 'Coffee'],
#  ['Scandinavian'],
#  ['Pastry', 'Medialuna'],
#  ['Brownie'],
#  ['Farm House'],
#  ['Coffee', 'Cookies'],
#  ['Soup'],
#  ['Art Tray', 'Coffee', 'Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Soup', 'Art Tray', 'Alfajores', 'Frittata'],
#  ['Sandwich', 'Coffee'],
#  ['Tea'],
#  ['Farm House'],
#  ['Scandinavian', 'Muffin'],
#  ['Farm House'],
#  ['Scandinavian'],
#  ['Soup'],
#  ['Hearty & Seasonal', 'Tea', 'Bread'],
#  ['Hot chocolate'],
#  ['Coffee', 'Sandwich', 'Hearty & Seasonal'],
#  ['Brownie', 'Hearty & Seasonal', 'Sandwich', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Coffee', 'Brownie', 'Soup'],
#  ['Sandwich', 'Sandwich', 'Alfajores', 'Alfajores', 'Focaccia'],
#  ['Farm House', 'Tartine'],
#  ['Bread'],
#  ['Coffee'],
#  ['Hot chocolate', 'Tea', 'Muffin'],
#  ['Pastry'],
#  ['Coffee', 'Brownie', 'Hearty & Seasonal', 'Soup', 'Bowl Nic Pitt'],
#  ['Coffee'],
#  ['Alfajores', 'Medialuna', 'Scandinavian', 'Farm House'],
#  ['Soup', 'Coffee'],
#  ['Tea', 'Tea'],
#  ['Coffee', 'Tea', 'Cookies'],
#  ['Tea', 'Muffin'],
#  ['Coffee', 'Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Coffee', 'Bread Pudding'],
#  ['Coffee', 'Medialuna'],
#  ['Hot chocolate'],
#  ['Coffee', 'Hot chocolate', 'Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Coffee', 'Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee', 'Hot chocolate'],
#  ['Bread'],
#  ['Coffee', 'Focaccia', 'Coffee', 'Medialuna', 'Bread'],
#  ['Coffee'],
#  ['Bread', 'Keeping It Local'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'NONE'],
#  ['Bread', 'Medialuna'],
#  ['Coffee'],
#  ['Coffee', 'Coffee', 'Medialuna'],
#  ['Coffee', 'Cookies', 'Tartine'],
#  ['Tea', 'Bread'],
#  ['Bread', 'Keeping It Local', 'Coffee'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee', 'Medialuna'],
#  ['Tea'],
#  ['Juice', 'Coke', 'Soup'],
#  ['Bread'],
#  ['Brownie'],
#  ['Brownie', 'Bread', 'Coffee'],
#  ['Coffee', 'Pastry', 'Bread', 'Hearty & Seasonal'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Bread', 'Cookies'],
#  ['Fudge', 'Eggs'],
#  ['Bread'],
#  ['Bread', 'Muffin'],
#  ['Soup'],
#  ['Coffee', 'Bread Pudding'],
#  ['Bread', 'Tartine'],
#  ['Sandwich', 'Coffee', 'Fudge', 'Jam', 'Bread Pudding'],
#  ['Bread Pudding', 'Soup', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Coffee', 'Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Bread', 'Soup'],
#  ['Soup', 'Tea', 'Focaccia'],
#  ['Coffee', 'My-5 Fruit Shoot', 'Cookies'],
#  ['Coffee', 'Coffee'],
#  ['Coffee', 'Sandwich', 'Tea'],
#  ['Scandinavian'],
#  ['Adjustment'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Medialuna', 'Brownie'],
#  ['Bread', 'Pastry', 'Brownie'],
#  ['Pastry', 'Bread', 'Cookies'],
#  ['Bread', 'Bread'],
#  ['Cookies', 'Pastry', 'Coffee', 'Juice'],
#  ['Pastry', 'Cookies', 'Coffee'],
#  ['Coffee', 'Medialuna'],
#  ['Bread'],
#  ['Tartine', 'Coffee'],
#  ['Coffee', 'Medialuna'],
#  ['Bread'],
#  ['Bread', 'Coffee', 'Alfajores', 'Cookies'],
#  ['Bread', 'Coffee', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee', 'Tea', 'Keeping It Local', 'Jam', 'Cookies'],
#  ['Pastry', 'Coffee', 'Juice'],
#  ['Medialuna', 'Bread', 'Focaccia'],
#  ['Pastry', 'Medialuna', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Cookies', 'Truffles', 'Brownie', 'Bread'],
#  ['Art Tray', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'Cookies'],
#  ['Brownie'],
#  ['Bread', 'Tea', 'Empanadas'],
#  ['Bread', 'Hot chocolate'],
#  ['Coffee', 'Cookies'],
#  ['Bread'],
#  ['Tartine', 'Sandwich', 'Tea', 'Bread'],
#  ['Soup', 'Sandwich', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Coffee', 'Empanadas', 'Soup'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Coffee', 'Smoothies', 'Juice', 'Soup', 'Hearty & Seasonal'],
#  ['Alfajores',
#   'Sandwich',
#   'Hot chocolate',
#   'Coffee',
#   'Scandinavian',
#   'Cookies'],
#  ['Tea', 'Coffee'],
#  ['Bread', 'Cookies'],
#  ['Alfajores', 'Cookies', 'Bread', 'Bread'],
#  ['Tea', 'Brownie'],
#  ['Tea', 'Bread'],
#  ['Coffee', 'Alfajores'],
#  ['Bread'],
#  ['Empanadas', 'Coffee'],
#  ['Bread'],
#  ['Coffee', 'Hot chocolate'],
#  ['Coffee'],
#  ['Coffee', 'Brownie'],
#  ['Tea', 'Hot chocolate', 'Brownie', 'Truffles'],
#  ['Coffee', 'Keeping It Local'],
#  ['Coffee'],
#  ['Alfajores'],
#  ['Scandinavian', 'Chimichurri Oil'],
#  ['Bread', 'Truffles'],
#  ['Brownie', 'Focaccia'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Tea', 'Art Tray', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Alfajores', 'Alfajores', 'Coke'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread', 'Pastry', 'Medialuna', 'Coffee'],
#  ['Coffee'],
#  ['Bread', 'Keeping It Local'],
#  ['Bread'],
#  ['Coffee', 'Scandinavian'],
#  ['Bread', 'Farm House', 'Pastry', 'Medialuna'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Bread', 'Farm House'],
#  ['Bread'],
#  ['Keeping It Local', 'Bread'],
#  ...]

# %%
# delete items repeated in each transactions, for example: ['Scandinavian', 'Scandinavian'] -> ['Scandinavian']
# delete 'NONE' in transactions, for example: ['Coffee', 'Bread', 'NONE'] -> ['Coffee', 'Bread']
# also delete 'Adjustment' and 'Keep it Local' (spam data) 
apyori_transactions = []
for x in transactions:
    x = list(set(x))
    if 'NONE' in x:
        x.remove('NONE')
    if 'Adjustment' in x:
        x.remove('Adjustment')
    if 'Keeping It Local' in x:
        x.remove('Keeping It Local')
    apyori_transactions.append(x)
apyori_transactions # 9531 transactions
# Out:
# [['Bread'],
#  ['Scandinavian'],
#  ['Hot chocolate', 'Jam', 'Cookies'],
#  ['Muffin'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Medialuna', 'Muffin', 'Pastry'],
#  ['Medialuna', 'Tea', 'Coffee', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Muffin'],
#  ['Medialuna', 'Scandinavian'],
#  ['Bread', 'Medialuna'],
#  ['Coffee', 'Tartine', 'Pastry', 'Tea', 'Jam'],
#  ['Bread', 'Basket', 'Coffee'],
#  ['Bread', 'Pastry', 'Medialuna'],
#  ['Scandinavian', 'Mineral water'],
#  ['Bread', 'Coffee', 'Medialuna'],
#  ['Hot chocolate'],
#  ['Farm House'],
#  ['Farm House', 'Bread'],
#  ['Bread', 'Medialuna'],
#  ['Medialuna', 'Bread', 'Coffee'],
#  ['Jam'],
#  ['Scandinavian', 'Muffin'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Jam'],
#  ['Bread'],
#  ['Basket'],
#  ['Scandinavian', 'Muffin'],
#  ['Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Scandinavian', 'Muffin'],
#  ['Bread', 'Tea'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Tea'],
#  ['Scandinavian'],
#  ['Coffee', 'Tartine', 'Juice', 'Muffin'],
#  ['Scandinavian'],
#  ['Bread', 'Tea'],
#  ['Fudge', 'Scandinavian'],
#  ['Medialuna', 'Coffee'],
#  ['Medialuna', 'Coffee', 'Hot chocolate'],
#  ['Coffee'],
#  ['Muffin', 'Bread', "Ella's Kitchen Pouches", 'Juice', 'Jam'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Victorian Sponge', 'Bread'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Hearty & Seasonal', 'Tea', 'Coffee', 'Frittata'],
#  ['Coffee', 'Frittata'],
#  ['Scandinavian'],
#  ['Victorian Sponge', 'Soup', 'Hot chocolate', 'Tea'],
#  ['Tea'],
#  ['Juice', 'Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Smoothies', 'Pick and Mix Bowls', 'Coffee'],
#  ['Coffee'],
#  ['Cake'],
#  ['Mighty Protein', 'Coffee', 'Tartine', 'Tea'],
#  ['Hearty & Seasonal', 'Mineral water', 'Frittata'],
#  ['Hearty & Seasonal', 'Muffin', 'Mineral water'],
#  ['Coffee', 'Scandinavian', 'Tea', 'Chicken sand', 'Frittata'],
#  ['Victorian Sponge', 'Bread', 'Tea'],
#  ['Fudge'],
#  ['Muffin'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Jam', 'Frittata'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Fudge', 'Coffee', 'Muffin', 'Tea'],
#  ['Bread', 'Coffee', 'Frittata'],
#  ['Coffee', 'Cake'],
#  ['Bread', 'Tartine'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Coffee', 'Pastry'],
#  ['Juice'],
#  ['Bread'],
#  ['Coffee', 'Jam'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Tea'],
#  ['Coffee'],
#  ['Bread', 'Coke'],
#  ['Coffee'],
#  ['Farm House', 'Pastry', 'Tea'],
#  ['Juice', 'Coffee', 'Pastry'],
#  ['Juice', 'Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Bread'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Bread'],
#  ['Medialuna', 'Coffee', 'Muffin'],
#  ['Coffee', 'Cake', 'Tea'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Tea'],
#  ['Farm House', 'Muffin'],
#  ['Bread', 'Muffin', 'Pastry'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Cake'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'My-5 Fruit Shoot', 'Cake', 'Cookies'],
#  ['Pastry', 'Tea', 'Cookies'],
#  ['Coffee', 'Muffin'],
#  ['Farm House'],
#  ['Bread', 'Coffee'],
#  ['Cookies'],
#  ['Juice', 'Jam', 'Coffee'],
#  ['Soup', 'Coffee'],
#  ['Tea'],
#  ['Coffee', 'Jam'],
#  ['Farm House'],
#  ['Tartine', 'Tea', 'Coffee'],
#  ['Coffee', 'Cake'],
#  ['Coffee', 'Muffin'],
#  ['Bread', 'Coffee'],
#  ['Cookies', 'Juice', 'Pick and Mix Bowls', 'Tea'],
#  ['Hearty & Seasonal', 'Soup'],
#  ['Hearty & Seasonal', 'Farm House', 'Tea'],
#  ['Bread'],
#  ['Soup', 'Tea'],
#  ['Farm House'],
#  ['Soup', 'Hearty & Seasonal', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread', 'Muffin'],
#  ['Coffee', 'Cookies'],
#  ['Bread'],
#  ['Muffin', 'Tea'],
#  ['Tea'],
#  ['Soup', 'Hearty & Seasonal'],
#  ['Focaccia', 'Coffee', 'Tea'],
#  ['Sandwich'],
#  ['Tartine', 'Coffee'],
#  ['Fudge', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Soup', 'Coke'],
#  ['Muffin'],
#  ['Cookies', 'Coffee', 'Muffin', 'Tea'],
#  ['Mighty Protein', 'Coke', 'Hearty & Seasonal', 'Coffee'],
#  ['Sandwich', 'Muffin', 'Tea'],
#  ['Coffee', 'Muffin'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Bread', 'Hot chocolate', 'Cookies'],
#  ['Muffin', 'Mineral water'],
#  ['Tea'],
#  ['Muffin'],
#  ['Juice', 'Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Tea'],
#  ['Coffee', 'Muffin'],
#  ['Hearty & Seasonal', 'Bread', 'Sandwich', 'Mineral water'],
#  ['Coffee', 'Tea'],
#  ['Mineral water'],
#  ['Coffee'],
#  ['Soup', 'Tea'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Cookies'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Jam', 'Tea'],
#  ['Tea'],
#  ["Ella's Kitchen Pouches", 'Pastry'],
#  ['Pastry'],
#  ['Farm House', 'Tea'],
#  ['Victorian Sponge', 'Tea'],
#  ['Pastry', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Soup', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Scandinavian'],
#  ['Bread', 'Cake', 'Cookies'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['Pastry', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread', 'Scandinavian'],
#  ['Coffee', 'Pastry'],
#  ['Scandinavian', 'Coffee', 'Pastry'],
#  ['Hearty & Seasonal', 'Coffee', 'Muffin'],
#  ['Bread'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Soup', 'Coffee'],
#  ['Tartine', 'Coffee', 'Cookies'],
#  ['Bread'],
#  ['Bread', 'Tea'],
#  ['Coffee', 'Pastry'],
#  ['Tartine', 'Coffee'],
#  ['Bread', 'Cookies'],
#  ['Sandwich'],
#  ['Tartine'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Scandinavian'],
#  ['Scandinavian'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Soup', 'Coke', 'Coffee'],
#  ['Cake'],
#  ['Soup', 'Sandwich', 'Tea'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Alfajores'],
#  ['Cake'],
#  ['Bread', 'Tea'],
#  ['Soup', 'Bread', 'Coffee', 'Tea'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Sandwich', 'Coffee'],
#  ['Bread', 'Pastry', 'Cookies', 'Tea'],
#  ['Muffin'],
#  ['Scandinavian'],
#  ['Jam', 'Tea'],
#  ['Alfajores', 'Juice', 'Tea'],
#  ['Soup', 'Cake', 'Muffin', 'Coffee'],
#  ['Hot chocolate', 'Cake', 'Coffee'],
#  ['Cake', 'Cookies'],
#  ['Bread', 'Tea'],
#  ['Alfajores', 'Juice', 'Coffee'],
#  ['Soup', 'Coffee', 'Tea'],
#  ['Hot chocolate'],
#  ['Cookies'],
#  ['Medialuna', 'Coffee'],
#  ['Bread', 'Eggs'],
#  ['Scandinavian'],
#  ['Medialuna'],
#  ['Coffee', 'Pastry'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Hot chocolate', 'Pastry'],
#  ['Coke'],
#  ['Coffee', 'Jam'],
#  ['Tea'],
#  ['Bread', 'Pastry'],
#  ['Alfajores', 'Farm House', 'Coffee'],
#  ['Pastry', 'Tea'],
#  ['Bread'],
#  ['Coffee', 'Jam'],
#  ['Pastry', 'Coffee', 'Tea'],
#  ['Farm House'],
#  ['Bread', 'Pastry', 'Coffee'],
#  ['Farm House'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Bread'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Farm House', 'Coffee'],
#  ['Farm House', 'Pastry'],
#  ['Alfajores', 'Bread', 'Juice'],
#  ['Coffee', 'Pastry'],
#  ['Alfajores', 'Bread'],
#  ['Bread'],
#  ['Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Cookies'],
#  ['Hearty & Seasonal'],
#  ['Coffee'],
#  ['Bread', 'Tartine', 'Jam'],
#  ['Farm House', 'Scandinavian'],
#  ['Hearty & Seasonal', 'Scandinavian', 'Coffee', 'Muffin'],
#  ['Coffee', 'Pick and Mix Bowls', 'Tartine', 'Coke'],
#  ['Bread'],
#  ['Alfajores', 'Farm House', 'Scandinavian', 'Coffee'],
#  ['Soup', 'Juice', 'Mineral water'],
#  ['Soup', 'Tea'],
#  ['Soup', 'Cookies', 'Juice', 'Tea'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Fudge'],
#  ['Soup', 'Juice', 'Coffee', 'Mineral water'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal', 'Smoothies'],
#  ['Hearty & Seasonal', 'Tea'],
#  ['Sandwich', 'Coffee'],
#  ['Farm House', 'Cookies'],
#  ['Soup', 'Juice', 'Tea'],
#  ['Soup'],
#  ['Coffee'],
#  ['Bread'],
#  ['Tea', 'Cookies'],
#  ['Soup', 'Bread', 'Hearty & Seasonal'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Tea'],
#  ['Coffee', 'Tea'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Tea'],
#  ['Soup', 'Tea'],
#  ['Juice'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Alfajores', 'Coffee'],
#  ['Cookies', 'Pick and Mix Bowls', 'Mineral water', 'Juice', 'Alfajores'],
#  ['Alfajores', 'Coffee'],
#  ['Fudge'],
#  ['Mighty Protein', 'Juice'],
#  ['Alfajores', 'Coffee', 'Mineral water'],
#  ['Mighty Protein', 'Coffee'],
#  ['Alfajores'],
#  ['Bread', 'Coffee'],
#  ['Medialuna'],
#  ['Medialuna', 'Bread'],
#  ['Farm House'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Pastry', 'Coffee'],
#  ['Medialuna'],
#  ['Bread', 'Sandwich', 'Tea'],
#  ['Bread'],
#  ['Farm House', 'Coffee', 'Jam'],
#  ['Focaccia'],
#  ['Bread'],
#  ['Bread', 'My-5 Fruit Shoot', 'Tartine', 'Pastry'],
#  ['Farm House', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Coffee', 'Jam'],
#  ['Farm House'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Coffee', 'Tea'],
#  ['Jam'],
#  ['Medialuna', 'Pastry'],
#  ['Coffee'],
#  ['Tea'],
#  ['Bread'],
#  ['Bread', 'Pastry'],
#  ['Pastry'],
#  ['Farm House'],
#  ['Tea'],
#  ['Alfajores', 'Fudge', 'Coffee', 'Brownie'],
#  ['Bread', 'Fudge', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Jam', 'Pastry'],
#  ['Soup', 'Coffee'],
#  ['Soup', 'Smoothies', 'Hearty & Seasonal', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Medialuna', 'Pastry'],
#  ['Coffee', 'Tea'],
#  ['Bread', 'Cookies'],
#  ['Coffee',
#   'Focaccia',
#   'Bread',
#   'Pick and Mix Bowls',
#   'Hearty & Seasonal',
#   'Sandwich'],
#  ['Coffee'],
#  ['Sandwich', 'Coffee', 'Brownie'],
#  ['Cookies', 'Brownie'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread', 'Sandwich', 'Coffee'],
#  ['Coffee', 'Hot chocolate'],
#  ['Tea'],
#  ['Sandwich', 'Coffee', 'Brownie'],
#  ['Farm House', 'Pastry', 'Focaccia', 'Brownie'],
#  ['Cake', 'Focaccia'],
#  ['Soup', 'Hearty & Seasonal', 'Mineral water'],
#  ['Hearty & Seasonal'],
#  ['Hearty & Seasonal'],
#  ['Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Cake', 'Tea'],
#  ['Soup', 'Coffee'],
#  ['Bread', 'Fudge', 'Focaccia'],
#  ['Alfajores', 'Hot chocolate', 'Coffee'],
#  ['Pastry', 'Cake', 'Brownie'],
#  ['Alfajores', 'Medialuna', 'Dulce de Leche'],
#  ['Alfajores', 'Dulce de Leche'],
#  ['Bread', 'Cake'],
#  ['Cake', 'Coffee'],
#  ['Bread'],
#  ['Sandwich'],
#  ['Alfajores', 'Bread', 'Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Alfajores', 'Bread'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Dulce de Leche'],
#  ['Farm House'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Coffee', 'Juice', 'Alfajores', "Ella's Kitchen Pouches", 'Brownie'],
#  ['Alfajores'],
#  ['Cookies', 'Bread', 'Juice', 'Alfajores', 'Brownie'],
#  ['Cake', 'Cookies'],
#  ['Pick and Mix Bowls'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Tea'],
#  ['Coffee'],
#  ['Farm House', 'Focaccia'],
#  ['Dulce de Leche'],
#  ['Cookies', 'Juice', "Ella's Kitchen Pouches", 'My-5 Fruit Shoot'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Bread', 'Jam', 'Tea'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Pastry'],
#  ['Coffee', 'Jam'],
#  ['Bread', 'Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Hot chocolate'],
#  ['Bread', 'Medialuna'],
#  ['Bread', 'Jam'],
#  ['Bread', 'Jam'],
#  ['Bread', 'Coffee'],
#  ['Bread', 'Farm House'],
#  ['Bread', 'Coffee'],
#  ['Pastry', 'Tea'],
#  ['Coffee'],
#  ['Bread'],
#  ['Brownie', 'Pastry'],
#  ['Farm House'],
#  ['Coffee'],
#  ['Cookies', 'Honey', 'Coffee', 'Tea'],
#  ['Tea'],
#  ['Bread'],
#  ['Brownie'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Tea'],
#  ['Tea'],
#  ['Coffee'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'The BART'],
#  ['Brownie', 'Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Brownie'],
#  ['Tartine', 'Coffee', 'Mineral water'],
#  ['Coffee', 'Brownie'],
#  ['Juice', 'Brownie'],
#  ['Coffee', 'Bread', 'Pastry', 'Tea', 'Alfajores', 'Medialuna', 'Jam'],
#  ['Bread'],
#  ['Fudge'],
#  ['Pick and Mix Bowls', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Soup', 'Scandinavian', 'Coffee', 'Mineral water'],
#  ['Sandwich', 'Juice', 'Pick and Mix Bowls', 'Mineral water'],
#  ['Bread', 'Pastry'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread', 'Coffee', 'Mineral water'],
#  ['Tartine', 'Sandwich', 'Coffee', 'Brownie'],
#  ['Coffee', 'Brownie'],
#  ['Alfajores', 'Tartine', 'Coffee'],
#  ['Mighty Protein', 'Coffee'],
#  ['Coffee', 'Hot chocolate'],
#  ['Soup', 'Coffee', 'Jam'],
#  ['Mineral water', 'Brownie'],
#  ['Scandinavian', 'Coffee'],
#  ['Scandinavian', 'Coffee'],
#  ['Coffee'],
#  ['Hearty & Seasonal', 'Coffee', 'Hot chocolate', 'Brownie'],
#  ['Cake', 'Tea'],
#  ['Medialuna'],
#  ['Alfajores', 'Coffee', 'Tea'],
#  ['Alfajores', 'Juice', 'Coffee', 'Brownie'],
#  ['Sandwich', 'Coffee'],
#  ['Soup', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Bread'],
#  ['Brownie', 'Cookies', 'Tea'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Brownie'],
#  ['Bread', 'Jam', 'Cookies'],
#  ['Coffee'],
#  ['Brownie', 'Tea'],
#  ['Alfajores', 'Medialuna', 'Scandinavian'],
#  ['Alfajores', 'Cookies', 'Hot chocolate', 'Coffee'],
#  ['Brownie'],
#  ['Fudge'],
#  ['Brownie', 'Tea'],
#  ['Dulce de Leche', 'Fudge'],
#  ['Fudge', 'Coffee', 'Bread', 'Scandinavian', 'Granola', 'Pastry'],
#  ['Bread', 'Fudge'],
#  ['Medialuna', 'Hot chocolate', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Medialuna'],
#  ['Bread', 'Coffee', 'Jam', 'Medialuna'],
#  ['Coffee', 'Jam', 'Brownie'],
#  ['Bread', 'Coffee', 'Jam'],
#  ['Scandinavian'],
#  ['Coffee', 'Cookies'],
#  ['Scandinavian', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Jam', 'Brownie'],
#  ['Coffee'],
#  ['Hot chocolate', 'Brownie'],
#  ['Bread'],
#  ['Bread', 'Medialuna'],
#  ['Coffee', 'Hot chocolate', 'Brownie'],
#  ['Scandinavian'],
#  ['Bread', 'Basket'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Fudge', 'Cake'],
#  ['Basket', 'Coffee', 'Hot chocolate'],
#  ['Scandinavian'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee', 'Cake', 'Medialuna'],
#  ['Medialuna', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Brownie'],
#  ['Medialuna', 'Farm House'],
#  ['Bread', 'Medialuna'],
#  ['Coffee', 'Hot chocolate', 'Smoothies', 'Medialuna', 'Brownie'],
#  ['Coffee', 'Bread', 'Tea', 'Medialuna', 'Brownie'],
#  ['Medialuna', 'Cookies'],
#  ['Medialuna', 'Coffee'],
#  ['Bread', 'Fudge'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Cookies'],
#  ['Brownie', 'Bread', 'Pastry'],
#  ['Bread', 'Coffee'],
#  ['Tea', 'Coffee'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Brownie', 'Coffee', 'My-5 Fruit Shoot'],
#  ['Fudge', 'Coffee'],
#  ['Coffee'],
#  ['Basket', 'Coffee'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Coffee', 'Brownie'],
#  ['My-5 Fruit Shoot', 'Scandinavian', 'Brownie'],
#  ['Hot chocolate', 'Coffee', 'Tartine', 'Brownie'],
#  ['Bread', 'Hot chocolate', 'Brownie'],
#  ['Fudge', 'Jam'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Mighty Protein', 'Coffee', 'Cake', 'Tea', 'Hearty & Seasonal'],
#  ['Coffee'],
#  ['Scandinavian'],
#  ['Victorian Sponge', 'Scandinavian', 'Cake'],
#  ['Cake', 'Tea'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Frittata'],
#  ['Brownie', 'Coffee', 'My-5 Fruit Shoot'],
#  ['Fairy Doors', 'Focaccia'],
#  ['Coffee', 'Tea'],
#  ['Hearty & Seasonal', 'Hot chocolate', 'Pick and Mix Bowls', 'Brownie'],
#  ['Coffee', 'Frittata'],
#  ['Bread', 'Brownie'],
#  ['Frittata'],
#  ['Scandinavian'],
#  ['Bread'],
#  ['Farm House'],
#  ['Soup', 'Pick and Mix Bowls', 'Jam', 'Brownie'],
#  ['Hearty & Seasonal', 'Coffee', 'Tea'],
#  ['Bread'],
#  ['Bread', 'Frittata'],
#  ['Scandinavian'],
#  ['Tartine', 'Hot chocolate', 'Coffee'],
#  ['Mighty Protein', 'Coffee'],
#  ['Coffee', 'Frittata'],
#  ['Scandinavian'],
#  ['Hearty & Seasonal', 'Coffee', 'Mineral water'],
#  ['Scandinavian'],
#  ['Bread', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread', 'Soup', 'Coffee'],
#  ['Tea', 'Cake', 'Brownie'],
#  ['Mighty Protein', 'Coffee'],
#  ['Brownie', 'Soup', 'Coffee', 'Tea'],
#  ['Cake'],
#  ['Hot chocolate', 'Cake', 'Coffee'],
#  ['Hearty & Seasonal', 'Coffee'],
#  ['Coffee'],
#  ['Brownie', 'Coffee', 'Frittata'],
#  ['Frittata', 'Mineral water', 'Coke', 'Sandwich', 'Brownie'],
#  ['Scandinavian', 'Granola'],
#  ['Coke', 'Coffee'],
#  ['Brownie', 'Cake', 'Tea'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Brownie'],
#  ['Cake'],
#  ['Tea'],
#  ['Soup', 'Sandwich', 'Coffee', 'Cake'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Coffee', 'Brownie'],
#  ['Soup', 'Coffee', 'Brownie'],
#  ['Fudge'],
#  ['Bread', 'Focaccia'],
#  ['Bread', 'Jam', 'Farm House'],
#  ['Hot chocolate', 'Brownie'],
#  ['Hot chocolate'],
#  ['Coffee', 'Brownie'],
#  ['Medialuna', 'Pastry'],
#  ['Bread'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Mineral water', 'Coffee'],
#  ['Bread', 'Hot chocolate', 'Pastry'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread', 'Coffee', 'Jam'],
#  ['Pastry', 'Coffee'],
#  ['Coffee', 'Focaccia', 'Hearty & Seasonal', 'Medialuna'],
#  ['Bread', 'Jam', 'Coffee', 'Farm House'],
#  ['Farm House'],
#  ['Medialuna', 'Pastry', 'Coffee', 'Tea'],
#  ['Medialuna', 'Coffee', 'Pastry'],
#  ['Farm House', 'Basket', 'Coffee', 'Hot chocolate'],
#  ['Farm House', 'Pastry'],
#  ['My-5 Fruit Shoot', 'Hot chocolate', 'Coffee'],
#  ['Medialuna', 'Muffin', 'Pastry'],
#  ['Farm House'],
#  ['Focaccia', 'Muffin', 'Pastry'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Focaccia'],
#  ['Jam', 'Coffee', 'Hot chocolate', 'Pastry'],
#  ['Bread'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Tea'],
#  ['Hot chocolate', 'Mineral water', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Jam', 'Coffee'],
#  ['Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread'],
#  ['Hot chocolate', 'Muffin', 'Coffee'],
#  ['Fudge', 'Muffin'],
#  ['Bread'],
#  ['Bread'],
#  ['Farm House'],
#  ['Coffee', 'Muffin'],
#  ['Focaccia'],
#  ['Bread', 'Tea'],
#  ['Coffee', 'Hot chocolate'],
#  ['Pick and Mix Bowls', 'Tartine', 'Coffee', 'Jam'],
#  ['Jam'],
#  ['Tartine'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Pick and Mix Bowls', 'Tartine', 'Mineral water', 'Juice'],
#  ['Bread', 'Juice', 'Tea'],
#  ['Coffee', 'Cake'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Coffee', 'Cake', 'Brownie'],
#  ['Coffee', 'Focaccia'],
#  ['Coffee', 'Muffin', 'Tea'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Hearty & Seasonal', 'Cake', 'Coffee'],
#  ['Bread', 'Cake', 'Tea'],
#  ['Mighty Protein', 'Coffee'],
#  ['Hot chocolate', 'Muffin'],
#  ['Soup', 'Coffee', 'Mighty Protein'],
#  ['Jam'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Cake', 'Hot chocolate'],
#  ['Hot chocolate', 'Muffin', 'Tea'],
#  ['Brownie'],
#  ['Cake', 'Coffee'],
#  ['Victorian Sponge', 'Alfajores', 'Tea'],
#  ['Bread'],
#  ['Tartine', 'Tea'],
#  ['Mighty Protein', 'Tea'],
#  ['Bread', 'Fudge'],
#  ['Medialuna', 'Tartine', 'Coffee'],
#  ['Bread', 'Pastry'],
#  ['Bread', 'Pastry'],
#  ['Alfajores', 'Coffee', 'Tea'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Alfajores', 'Pastry'],
#  ['Alfajores'],
#  ['Alfajores', 'Hearty & Seasonal', 'Tea', 'Pastry'],
#  ['Sandwich', 'Tea'],
#  ['Empanadas', 'Tea'],
#  ['Alfajores', 'Tea'],
#  ['Alfajores'],
#  ['Dulce de Leche', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Farm House', 'Coffee'],
#  ['Bread', 'Scandinavian', 'Medialuna'],
#  ['Bread'],
#  ['Alfajores', 'Tea', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Bread', 'Farm House', 'Muffin', 'Pastry'],
#  ['Medialuna', 'Tea'],
#  ['Alfajores'],
#  ['Sandwich', 'Tea'],
#  ['Bread', 'Tea'],
#  ['Bread', 'Coffee', 'Pastry'],
#  ['Alfajores', 'Empanadas', 'Coffee', 'Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Medialuna', 'Tea', 'Pastry'],
#  ['Bread', 'Tea'],
#  ['Muffin'],
#  ['Coffee', 'Muffin'],
#  ['Bread', 'Medialuna', 'Coffee', 'Pastry'],
#  ['Coffee', 'Muffin'],
#  ['Bread', 'Scandinavian', 'Hot chocolate', 'Muffin'],
#  ['Farm House'],
#  ['Muffin'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Muffin'],
#  ['Coffee', 'Tea'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Scandinavian', 'Tartine'],
#  ['Coffee', 'Tea'],
#  ['Bread'],
#  ['Coke', 'Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Coffee', 'Bread', 'Scandinavian', 'Medialuna', 'Muffin'],
#  ['Bread'],
#  ['Coke'],
#  ['Bread', 'Scandinavian'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Scandinavian'],
#  ['Fudge'],
#  ['Soup', 'Hearty & Seasonal', 'Coffee'],
#  ['Coke'],
#  ['Cookies', 'Tea', 'Coffee'],
#  ['Tea', 'Coffee', 'Pastry'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Soup', 'Sandwich', 'Coffee', 'Muffin'],
#  ['Coffee', 'Muffin', 'Tea'],
#  ['Alfajores'],
#  ['Bread'],
#  ['Medialuna', 'Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Medialuna'],
#  ['Empanadas', 'Bread', 'Scandinavian'],
#  ['Tartine', 'Coffee'],
#  ['Tea'],
#  ['Scandinavian'],
#  ['Muffin'],
#  ['Bread', 'Scandinavian'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Scandinavian', 'Cookies'],
#  ['Bread', 'Empanadas', 'Coffee', 'Medialuna'],
#  ['Coffee', 'Pastry'],
#  ['Bread'],
#  ['Tea', 'Pastry'],
#  ['Coffee', 'Pastry'],
#  ['Bread', 'Coffee'],
#  ['Coffee'],
#  ['Fudge'],
#  ['Tartine', 'Coffee'],
#  ['Medialuna', 'Pastry', 'Hot chocolate', 'Coffee'],
#  ['Alfajores', 'Coffee'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Coke'],
#  ['Alfajores', 'Coffee'],
#  ['Muffin'],
#  ['Farm House', 'Fudge', 'Brownie'],
#  ['Coffee'],
#  ['Farm House', 'Muffin', 'Tea'],
#  ['Coffee', 'Pastry'],
#  ['Brownie', 'Pastry'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Juice', 'Coffee', 'Pastry'],
#  ['Bread', 'Coffee'],
#  ['Coffee', 'Tea'],
#  ['Alfajores', 'Tea'],
#  ['Alfajores', 'Coffee'],
#  ['Scandinavian'],
#  ['Medialuna', 'Pastry'],
#  ['Brownie'],
#  ['Farm House'],
#  ['Coffee', 'Cookies'],
#  ['Soup'],
#  ['Art Tray', 'Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Soup', 'Art Tray', 'Alfajores', 'Frittata'],
#  ['Sandwich', 'Coffee'],
#  ['Tea'],
#  ['Farm House'],
#  ['Scandinavian', 'Muffin'],
#  ['Farm House'],
#  ['Scandinavian'],
#  ['Soup'],
#  ['Hearty & Seasonal', 'Bread', 'Tea'],
#  ['Hot chocolate'],
#  ['Hearty & Seasonal', 'Sandwich', 'Coffee'],
#  ['Hearty & Seasonal', 'Sandwich', 'Coffee', 'Brownie'],
#  ['Medialuna', 'Coffee'],
#  ['Soup', 'Coffee', 'Brownie'],
#  ['Alfajores', 'Sandwich', 'Focaccia'],
#  ['Farm House', 'Tartine'],
#  ['Bread'],
#  ['Coffee'],
#  ['Hot chocolate', 'Muffin', 'Tea'],
#  ['Pastry'],
#  ['Coffee', 'Bowl Nic Pitt', 'Soup', 'Hearty & Seasonal', 'Brownie'],
#  ['Coffee'],
#  ['Alfajores', 'Medialuna', 'Scandinavian', 'Farm House'],
#  ['Soup', 'Coffee'],
#  ['Tea'],
#  ['Cookies', 'Coffee', 'Tea'],
#  ['Muffin', 'Tea'],
#  ['Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Bread Pudding', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Hot chocolate'],
#  ['Farm House', 'Coffee', 'Hot chocolate'],
#  ['Coffee', 'Pastry'],
#  ['Bread'],
#  ['Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Bread'],
#  ['Coffee', 'Hot chocolate'],
#  ['Bread'],
#  ['Medialuna', 'Bread', 'Coffee', 'Focaccia'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Bread', 'Medialuna'],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Tartine', 'Coffee', 'Cookies'],
#  ['Bread', 'Tea'],
#  ['Bread', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Tea'],
#  ['Soup', 'Coke', 'Juice'],
#  ['Bread'],
#  ['Brownie'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Hearty & Seasonal', 'Bread', 'Coffee', 'Pastry'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Bread', 'Cookies'],
#  ['Eggs', 'Fudge'],
#  ['Bread'],
#  ['Bread', 'Muffin'],
#  ['Soup'],
#  ['Bread Pudding', 'Coffee'],
#  ['Bread', 'Tartine'],
#  ['Fudge', 'Bread Pudding', 'Coffee', 'Sandwich', 'Jam'],
#  ['Soup', 'Bread Pudding', 'Coffee'],
#  ['Hearty & Seasonal', 'Bread'],
#  ['Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Bread'],
#  ['Soup', 'Bread', 'Coffee'],
#  ['Soup', 'Focaccia', 'Tea'],
#  ['Cookies', 'Coffee', 'My-5 Fruit Shoot'],
#  ['Coffee'],
#  ['Sandwich', 'Coffee', 'Tea'],
#  ['Scandinavian'],
#  [],
#  ['Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Pastry'],
#  ['Farm House'],
#  ['Medialuna', 'Brownie'],
#  ['Brownie', 'Bread', 'Pastry'],
#  ['Bread', 'Cookies', 'Pastry'],
#  ['Bread'],
#  ['Pastry', 'Juice', 'Coffee', 'Cookies'],
#  ['Cookies', 'Coffee', 'Pastry'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Tartine', 'Coffee'],
#  ['Medialuna', 'Coffee'],
#  ['Bread'],
#  ['Alfajores', 'Bread', 'Coffee', 'Cookies'],
#  ['Bread', 'Coffee'],
#  ['Bread'],
#  ['Coffee', 'Cookies', 'Bread', 'Tea', 'Jam'],
#  ['Juice', 'Coffee', 'Pastry'],
#  ['Medialuna', 'Bread', 'Focaccia'],
#  ['Medialuna', 'Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Cookies', 'Bread', 'Truffles', 'Brownie'],
#  ['Art Tray', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'Cookies'],
#  ['Brownie'],
#  ['Bread', 'Empanadas', 'Tea'],
#  ['Bread', 'Hot chocolate'],
#  ['Coffee', 'Cookies'],
#  ['Bread'],
#  ['Bread', 'Sandwich', 'Tartine', 'Tea'],
#  ['Soup', 'Bread', 'Sandwich'],
#  ['Soup', 'Bread'],
#  ['Fudge'],
#  ['Coffee'],
#  ['Soup', 'Empanadas', 'Coffee'],
#  ['Bread', 'Coffee', 'Brownie'],
#  ['Coffee', 'Smoothies', 'Soup', 'Juice', 'Hearty & Seasonal'],
#  ['Hot chocolate',
#   'Coffee',
#   'Cookies',
#   'Scandinavian',
#   'Alfajores',
#   'Sandwich'],
#  ['Coffee', 'Tea'],
#  ['Bread', 'Cookies'],
#  ['Alfajores', 'Bread', 'Cookies'],
#  ['Brownie', 'Tea'],
#  ['Bread', 'Tea'],
#  ['Alfajores', 'Coffee'],
#  ['Bread'],
#  ['Empanadas', 'Coffee'],
#  ['Bread'],
#  ['Coffee', 'Hot chocolate'],
#  ['Coffee'],
#  ['Coffee', 'Brownie'],
#  ['Brownie', 'Truffles', 'Hot chocolate', 'Tea'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Alfajores'],
#  ['Chimichurri Oil', 'Scandinavian'],
#  ['Bread', 'Truffles'],
#  ['Focaccia', 'Brownie'],
#  ['Bread', 'Coffee'],
#  ['Art Tray', 'Cookies', 'Coffee', 'Tea'],
#  ['Coffee'],
#  ['Bread'],
#  ['Alfajores', 'Coke', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Bread', 'Medialuna', 'Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Scandinavian', 'Coffee'],
#  ['Bread', 'Medialuna', 'Farm House', 'Pastry'],
#  ['Medialuna'],
#  ['Coffee'],
#  ['Bread', 'Farm House'],
#  ['Bread'],
#  ['Bread'],
#  ...]

# %% [markdown]
# Note: apyori_transactions list is acceptable data type for apyori.apriori

# %% [markdown]
#  **Find the best sellers and high frequent itemsets**

# %% [markdown]
# For problems related to frequency, we should use mlxtend.frequent_patterns instead of apyori. Unlike apyori, The mlxtend.frequent_patterns.apriori function expects data in a one-hot encoded pandas DataFrame.

# %% [markdown]
# Data preprocessing for mlxtend.frequent_patterns

# %%
te = TransactionEncoder()
te_ary = te.fit(apyori_transactions).transform(apyori_transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#    Afternoon with the baker  Alfajores  Argentina Night  Art Tray  Bacon  \
# 0                     False      False            False     False  False
# 1                     False      False            False     False  False
# 2                     False      False            False     False  False
# 3                     False      False            False     False  False
# 4                     False      False            False     False  False
#
#    Baguette  Bakewell  Bare Popcorn  Basket  Bowl Nic Pitt  ...  The BART  \
# 0     False     False         False   False          False  ...     False
# 1     False     False         False   False          False  ...     False
# 2     False     False         False   False          False  ...     False
# 3     False     False         False   False          False  ...     False
# 4     False     False         False   False          False  ...     False
#
#    The Nomad  Tiffin  Toast  Truffles  Tshirt  Valentine's card  Vegan Feast  \
# 0      False   False  False     False   False             False        False
# 1      False   False  False     False   False             False        False
# 2      False   False  False     False   False             False        False
# 3      False   False  False     False   False             False        False
# 4      False   False  False     False   False             False        False
#
#    Vegan mincepie  Victorian Sponge
# 0           False             False
# 1           False             False
# 2           False             False
# 3           False             False
# 4           False             False
#
# [5 rows x 92 columns]

# %% [markdown]
# Get high frequent itemsets (include single product) with support >= 4% or 380/9531 transactions

# %%
high_frequency_df = frequent_patterns.apriori(df, min_support=0.04, use_colnames=True)
high_frequency_df = high_frequency_df.sort_values(by='support', ascending=False).reset_index(drop=True)
high_frequency_df
# Out:
#      support          itemsets
# 0   0.475081          (Coffee)
# 1   0.324940           (Bread)
# 2   0.141643             (Tea)
# 3   0.103137            (Cake)
# 4   0.089393   (Bread, Coffee)
# 5   0.085510          (Pastry)
# 6   0.071346        (Sandwich)
# 7   0.061379       (Medialuna)
# 8   0.057916   (Hot chocolate)
# 9   0.054349    (Cake, Coffee)
# 10  0.054034         (Cookies)
# 11  0.049523     (Coffee, Tea)
# 12  0.047214  (Coffee, Pastry)

# %% [markdown]
# - The best seller is coffee. This product is in 4480/9531 transactions.
# - Some high frequent itemsets: (bread, coffee), (cake, coffee), (coffee, tea), (pastry, coffee)

# %% [markdown]
# **Find high correlation itemsets**

# %%
# we choose min_supprt=0.002 (19/9531 transactions)
association_rule = apyori.apriori(apyori_transactions, min_length=2, min_support=0.001, min_lift=1.5, min_confidence=0.2)

association_result = list(association_rule)
print("Number of rules: ", len(association_result))
# Out:
# Number of rules:  59

# %%
association_result
# Out:
# [RelationRecord(items=frozenset({'Art Tray', 'Tea'}), support=0.001154128632882174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Art Tray'}), items_add=frozenset({'Tea'}), confidence=0.28947368421052627, lift=2.0436842105263153)]),
#  RelationRecord(items=frozenset({'Bakewell', 'Tea'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bakewell'}), items_add=frozenset({'Tea'}), confidence=0.25, lift=1.765)]),
#  RelationRecord(items=frozenset({'Bread', 'Eggs'}), support=0.0014688909873045851, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Eggs'}), items_add=frozenset({'Bread'}), confidence=0.5, lift=1.5387471746851793)]),
#  RelationRecord(items=frozenset({'Jammie Dodgers', 'Cake'}), support=0.0030427027594166402, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jammie Dodgers'}), items_add=frozenset({'Cake'}), confidence=0.23199999999999998, lift=2.249432349949135)]),
#  RelationRecord(items=frozenset({'Cake', 'Tea'}), support=0.023607176581680833, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Tea'}), confidence=0.2288911495422177, lift=1.615971515768057)]),
#  RelationRecord(items=frozenset({'Vegan mincepie', 'Cake'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Vegan mincepie'}), items_add=frozenset({'Cake'}), confidence=0.23076923076923075, lift=2.237499021832694)]),
#  RelationRecord(items=frozenset({'Chicken Stew', 'Tea'}), support=0.0031476235442241107, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew'}), items_add=frozenset({'Tea'}), confidence=0.24390243902439024, lift=1.721951219512195)]),
#  RelationRecord(items=frozenset({'Extra Salami or Feta', 'Coffee'}), support=0.003252544329031581, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Coffee'}), confidence=0.8157894736842104, lift=1.717157569276548)]),
#  RelationRecord(items=frozenset({'Coke', 'Sandwich'}), support=0.005141118455566048, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Sandwich'}), confidence=0.266304347826087, lift=3.732568734015346)]),
#  RelationRecord(items=frozenset({'Extra Salami or Feta', 'Salad'}), support=0.0016787325569195257, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Salad'}), confidence=0.42105263157894735, lift=40.535885167464116)]),
#  RelationRecord(items=frozenset({'Tea', 'Frittata'}), support=0.0018885741265344666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Frittata'}), items_add=frozenset({'Tea'}), confidence=0.2222222222222222, lift=1.5688888888888888)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Mineral water'}), support=0.003252544329031581, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mineral water'}), items_add=frozenset({'Sandwich'}), confidence=0.23134328358208955, lift=3.2425482879719056)]),
#  RelationRecord(items=frozenset({'Smoothies', 'Sandwich'}), support=0.0017836533417269962, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Smoothies'}), items_add=frozenset({'Sandwich'}), confidence=0.22077922077922077, lift=3.0944805194805194)]),
#  RelationRecord(items=frozenset({'Scone', 'Tea'}), support=0.00828874199979016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Scone'}), items_add=frozenset({'Tea'}), confidence=0.24159021406727832, lift=1.705626911314985)]),
#  RelationRecord(items=frozenset({'Soup', 'Tea'}), support=0.00902318749344245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup'}), items_add=frozenset({'Tea'}), confidence=0.26380368098159507, lift=1.8624539877300612)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Tea'}), support=0.004616514531528696, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Tea'}), confidence=0.2558139534883721, lift=1.806046511627907)]),
#  RelationRecord(items=frozenset({'The Nomad', 'Tea'}), support=0.0017836533417269962, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Nomad'}), items_add=frozenset({'Tea'}), confidence=0.2931034482758621, lift=2.0693103448275862)]),
#  RelationRecord(items=frozenset({'Tiffin', 'Tea'}), support=0.003462385898646522, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tiffin'}), items_add=frozenset({'Tea'}), confidence=0.22602739726027396, lift=1.5957534246575342)]),
#  RelationRecord(items=frozenset({'Alfajores', 'Juice', 'Cookies'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores', 'Cookies'}), items_add=frozenset({'Juice'}), confidence=0.4347826086956522, lift=11.353186420488388), OrderedStatistic(items_base=frozenset({'Alfajores', 'Juice'}), items_add=frozenset({'Cookies'}), confidence=0.34482758620689663, lift=6.381653833277538)]),
#  RelationRecord(items=frozenset({'Alfajores', 'Hot chocolate', 'Tea'}), support=0.001154128632882174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores', 'Hot chocolate'}), items_add=frozenset({'Tea'}), confidence=0.32352941176470584, lift=2.284117647058823)]),
#  RelationRecord(items=frozenset({'Alfajores', 'Tea', 'Pastry'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores', 'Pastry'}), items_add=frozenset({'Tea'}), confidence=0.32258064516129037, lift=2.27741935483871)]),
#  RelationRecord(items=frozenset({'Jammie Dodgers', 'Bread', 'Cake'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jammie Dodgers', 'Bread'}), items_add=frozenset({'Cake'}), confidence=0.34090909090909094, lift=3.3053962822528438), OrderedStatistic(items_base=frozenset({'Jammie Dodgers', 'Cake'}), items_add=frozenset({'Bread'}), confidence=0.5172413793103449, lift=1.5918074220881167)]),
#  RelationRecord(items=frozenset({'Bread', 'Juice', 'Cake'}), support=0.0017836533417269962, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread', 'Juice'}), items_add=frozenset({'Cake'}), confidence=0.24285714285714285, lift=2.35470135154774)]),
#  RelationRecord(items=frozenset({'Jammie Dodgers', 'Bread', 'Tea'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jammie Dodgers', 'Bread'}), items_add=frozenset({'Tea'}), confidence=0.22727272727272732, lift=1.604545454545455)]),
#  RelationRecord(items=frozenset({'Soup', 'Bread', 'Tea'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup', 'Bread'}), items_add=frozenset({'Tea'}), confidence=0.24193548387096775, lift=1.7080645161290322)]),
#  RelationRecord(items=frozenset({'Bread', 'Tiffin', 'Tea'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread', 'Tiffin'}), items_add=frozenset({'Tea'}), confidence=0.2608695652173913, lift=1.8417391304347825)]),
#  RelationRecord(items=frozenset({'Tea', 'Cake', 'Brownie'}), support=0.0013639702024971147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake', 'Brownie'}), items_add=frozenset({'Tea'}), confidence=0.30952380952380953, lift=2.185238095238095), OrderedStatistic(items_base=frozenset({'Tea', 'Brownie'}), items_add=frozenset({'Cake'}), confidence=0.203125, lift=1.9694652848423193)]),
#  RelationRecord(items=frozenset({'Cake', 'Hot chocolate', 'Coffee'}), support=0.006819851012485573, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee', 'Hot chocolate'}), items_add=frozenset({'Cake'}), confidence=0.23214285714285712, lift=2.250817468391222)]),
#  RelationRecord(items=frozenset({'Cake', 'Salad', 'Coffee'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake', 'Salad'}), items_add=frozenset({'Coffee'}), confidence=0.7692307692307693, lift=1.6191560206577875)]),
#  RelationRecord(items=frozenset({'Smoothies', 'Cake', 'Coffee'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Smoothies', 'Coffee'}), items_add=frozenset({'Cake'}), confidence=0.2631578947368421, lift=2.5515339722653527)]),
#  RelationRecord(items=frozenset({'Tea', 'Cake', 'Coffee'}), support=0.009967474556709684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee', 'Tea'}), items_add=frozenset({'Cake'}), confidence=0.20127118644067798, lift=1.9514910253978655)]),
#  RelationRecord(items=frozenset({'Toast', 'Cake', 'Coffee'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Toast', 'Cake'}), items_add=frozenset({'Coffee'}), confidence=0.7142857142857143, lift=1.5035020191822313)]),
#  RelationRecord(items=frozenset({'Vegan mincepie', 'Cake', 'Coffee'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Vegan mincepie', 'Cake'}), items_add=frozenset({'Coffee'}), confidence=0.8333333333333334, lift=1.7540856890459364), OrderedStatistic(items_base=frozenset({'Vegan mincepie', 'Coffee'}), items_add=frozenset({'Cake'}), confidence=0.33333333333333337, lift=3.2319430315361144)]),
#  RelationRecord(items=frozenset({'Cake', 'Hot chocolate', 'Tea'}), support=0.001993494911341937, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hot chocolate', 'Tea'}), items_add=frozenset({'Cake'}), confidence=0.25, lift=2.4239572736520856)]),
#  RelationRecord(items=frozenset({'Juice', 'Cake', 'Tea'}), support=0.0014688909873045851, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice', 'Tea'}), items_add=frozenset({'Cake'}), confidence=0.2058823529411765, lift=1.9962001077134823)]),
#  RelationRecord(items=frozenset({'Medialuna', 'Cake', 'Tea'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Medialuna', 'Cake'}), items_add=frozenset({'Tea'}), confidence=0.34285714285714286, lift=2.4205714285714284)]),
#  RelationRecord(items=frozenset({'Cake', 'Muffin', 'Tea'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake', 'Muffin'}), items_add=frozenset({'Tea'}), confidence=0.2608695652173913, lift=1.8417391304347825)]),
#  RelationRecord(items=frozenset({'Tea', 'Cake', 'Pastry'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake', 'Pastry'}), items_add=frozenset({'Tea'}), confidence=0.24489795918367346, lift=1.7289795918367346)]),
#  RelationRecord(items=frozenset({'Soup', 'Sandwich', 'Cake'}), support=0.001154128632882174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup', 'Cake'}), items_add=frozenset({'Sandwich'}), confidence=0.2619047619047619, lift=3.6709033613445383), OrderedStatistic(items_base=frozenset({'Soup', 'Sandwich'}), items_add=frozenset({'Cake'}), confidence=0.2115384615384615, lift=2.051040770013303)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Cake', 'Tea'}), support=0.0014688909873045851, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Sandwich', 'Cake'}), items_add=frozenset({'Tea'}), confidence=0.2153846153846154, lift=1.5206153846153847)]),
#  RelationRecord(items=frozenset({'Scone', 'Cake', 'Tea'}), support=0.0017836533417269962, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Scone', 'Cake'}), items_add=frozenset({'Tea'}), confidence=0.3777777777777778, lift=2.667111111111111), OrderedStatistic(items_base=frozenset({'Scone', 'Tea'}), items_add=frozenset({'Cake'}), confidence=0.2151898734177215, lift=2.08644423554863)]),
#  RelationRecord(items=frozenset({'Soup', 'Cake', 'Tea'}), support=0.0018885741265344666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup', 'Cake'}), items_add=frozenset({'Tea'}), confidence=0.4285714285714286, lift=3.025714285714286), OrderedStatistic(items_base=frozenset({'Soup', 'Tea'}), items_add=frozenset({'Cake'}), confidence=0.20930232558139536, lift=2.029359577941281)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Chicken Stew', 'Coffee'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew', 'Coffee'}), items_add=frozenset({'Sandwich'}), confidence=0.20408163265306126, lift=2.860444177671069)]),
#  RelationRecord(items=frozenset({'Coke', 'Sandwich', 'Coffee'}), support=0.001993494911341937, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke', 'Coffee'}), items_add=frozenset({'Sandwich'}), confidence=0.3114754098360656, lift=4.36569431051109)]),
#  RelationRecord(items=frozenset({'Scone', 'Coffee', 'Cookies'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Scone', 'Cookies'}), items_add=frozenset({'Coffee'}), confidence=0.7894736842105262, lift=1.6617653896224658)]),
#  RelationRecord(items=frozenset({'Extra Salami or Feta', 'Coffee', 'Salad'}), support=0.0014688909873045851, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Coffee', 'Salad'}), confidence=0.3684210526315789, lift=56.635823429541595), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Coffee'}), items_add=frozenset({'Salad'}), confidence=0.4516129032258065, lift=43.478005865102645), OrderedStatistic(items_base=frozenset({'Coffee', 'Salad'}), items_add=frozenset({'Extra Salami or Feta'}), confidence=0.22580645161290325, lift=56.635823429541595), OrderedStatistic(items_base=frozenset({'Extra Salami or Feta', 'Salad'}), items_add=frozenset({'Coffee'}), confidence=0.8750000000000001, lift=1.8417899734982335)]),
#  RelationRecord(items=frozenset({'Hearty & Seasonal', 'Sandwich', 'Coffee'}), support=0.0012590494176896443, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hearty & Seasonal', 'Coffee'}), items_add=frozenset({'Sandwich'}), confidence=0.2222222222222222, lift=3.114705882352941), OrderedStatistic(items_base=frozenset({'Hearty & Seasonal', 'Sandwich'}), items_add=frozenset({'Coffee'}), confidence=0.8571428571428571, lift=1.8042024230186773)]),
#  RelationRecord(items=frozenset({'Jammie Dodgers', 'Juice', 'Coffee'}), support=0.0013639702024971147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jammie Dodgers', 'Coffee'}), items_add=frozenset({'Juice'}), confidence=0.20634920634920637, lift=5.388258317025441)]),
#  RelationRecord(items=frozenset({'Juice', 'Coffee', 'Pastry'}), support=0.0017836533417269962, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice', 'Pastry'}), items_add=frozenset({'Coffee'}), confidence=0.7727272727272728, lift=1.6265158207516865)]),
#  RelationRecord(items=frozenset({'Spanish Brunch', 'Juice', 'Coffee'}), support=0.001993494911341937, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spanish Brunch', 'Juice'}), items_add=frozenset({'Coffee'}), confidence=0.7307692307692308, lift=1.5381982196248982)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Coffee', 'Mineral water'}), support=0.0014688909873045851, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee', 'Mineral water'}), items_add=frozenset({'Sandwich'}), confidence=0.2641509433962264, lift=3.7023862375138736)]),
#  RelationRecord(items=frozenset({'Toast', 'Coffee', 'Pastry'}), support=0.0013639702024971147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Toast', 'Pastry'}), items_add=frozenset({'Coffee'}), confidence=0.8666666666666667, lift=1.824249116607774)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Coffee', 'Salad'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee', 'Salad'}), items_add=frozenset({'Sandwich'}), confidence=0.24193548387096775, lift=3.391010436432638), OrderedStatistic(items_base=frozenset({'Sandwich', 'Salad'}), items_add=frozenset({'Coffee'}), confidence=0.8333333333333333, lift=1.7540856890459362)]),
#  RelationRecord(items=frozenset({'Soup', 'Sandwich', 'Coffee'}), support=0.0035673066834539923, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup', 'Coffee'}), items_add=frozenset({'Sandwich'}), confidence=0.22666666666666666, lift=3.177)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Truffles', 'Coffee'}), support=0.0020984156961494074, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Truffles', 'Coffee'}), items_add=frozenset({'Sandwich'}), confidence=0.28169014084507044, lift=3.9482187241093625)]),
#  RelationRecord(items=frozenset({'Coke', 'Sandwich', 'Juice'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke', 'Juice'}), items_add=frozenset({'Sandwich'}), confidence=0.4761904761904763, lift=6.674369747899162), OrderedStatistic(items_base=frozenset({'Coke', 'Sandwich'}), items_add=frozenset({'Juice'}), confidence=0.20408163265306126, lift=5.329046687168019)]),
#  RelationRecord(items=frozenset({'Juice', 'Tea', 'Cookies'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice', 'Cookies'}), items_add=frozenset({'Tea'}), confidence=0.25862068965517243, lift=1.8258620689655174), OrderedStatistic(items_base=frozenset({'Juice', 'Tea'}), items_add=frozenset({'Cookies'}), confidence=0.22058823529411764, lift=4.0823814962878355)]),
#  RelationRecord(items=frozenset({'Soup', 'Sandwich', 'Tea'}), support=0.0015738117721120553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup', 'Sandwich'}), items_add=frozenset({'Tea'}), confidence=0.28846153846153844, lift=2.0365384615384614)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Tea', 'Cake', 'Coffee'}), support=0.0010492078480747037, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Sandwich', 'Cake', 'Coffee'}), items_add=frozenset({'Tea'}), confidence=0.22727272727272732, lift=1.604545454545455), OrderedStatistic(items_base=frozenset({'Sandwich', 'Cake', 'Tea'}), items_add=frozenset({'Coffee'}), confidence=0.7142857142857143, lift=1.5035020191822313)])]

# %% [markdown]
# association_result is complicated and it is very difficult to see. So, we convert it into a dataframe

# %%
# function to convert priori object into dataframe
def to_dataframe(apriori_obj):
    high_corr_df = pd.DataFrame(apriori_obj)

    high_corr_df['support_count'] = high_corr_df['support']*9531
    high_corr_df['items_base'] = high_corr_df.apply(lambda row: row['ordered_statistics'][0][0], axis=1)
    high_corr_df['items_add'] = high_corr_df.apply(lambda row: row['ordered_statistics'][0][1], axis=1)
    high_corr_df['confidence'] = high_corr_df.apply(lambda row: row['ordered_statistics'][0][2], axis=1)
    high_corr_df['lift'] = high_corr_df.apply(lambda row: row['ordered_statistics'][0][3], axis=1)

    high_corr_df = high_corr_df.sort_values(by='confidence', ascending=False).reset_index(drop=True).\
    drop(['ordered_statistics'], axis=1)
    
    return high_corr_df

# %%
high_corr_df = to_dataframe(association_result)
high_corr_df
# Out:
#                                     items   support  support_count  \
# 0                 (Toast, Coffee, Pastry)  0.001364           13.0
# 1          (Vegan mincepie, Cake, Coffee)  0.001049           10.0
# 2          (Extra Salami or Feta, Coffee)  0.003253           31.0
# 3                (Scone, Coffee, Cookies)  0.001574           15.0
# 4                 (Juice, Coffee, Pastry)  0.001784           17.0
# 5                   (Cake, Salad, Coffee)  0.001049           10.0
# 6         (Spanish Brunch, Juice, Coffee)  0.001993           19.0
# 7                   (Toast, Cake, Coffee)  0.001574           15.0
# 8                           (Bread, Eggs)  0.001469           14.0
# 9                 (Coke, Sandwich, Juice)  0.001049           10.0
# 10            (Alfajores, Juice, Cookies)  0.001049           10.0
# 11                      (Soup, Cake, Tea)  0.001889           18.0
# 12          (Extra Salami or Feta, Salad)  0.001679           16.0
# 13                     (Scone, Cake, Tea)  0.001784           17.0
# 14  (Extra Salami or Feta, Coffee, Salad)  0.001469           14.0
# 15                 (Medialuna, Cake, Tea)  0.001259           12.0
# 16          (Jammie Dodgers, Bread, Cake)  0.001574           15.0
# 17        (Alfajores, Hot chocolate, Tea)  0.001154           11.0
# 18               (Alfajores, Tea, Pastry)  0.001049           10.0
# 19               (Coke, Sandwich, Coffee)  0.001993           19.0
# 20                   (Tea, Cake, Brownie)  0.001364           13.0
# 21                       (The Nomad, Tea)  0.001784           17.0
# 22                        (Art Tray, Tea)  0.001154           11.0
# 23                  (Soup, Sandwich, Tea)  0.001574           15.0
# 24           (Sandwich, Truffles, Coffee)  0.002098           20.0
# 25                       (Coke, Sandwich)  0.005141           49.0
# 26      (Sandwich, Coffee, Mineral water)  0.001469           14.0
# 27                            (Soup, Tea)  0.009023           86.0
# 28              (Smoothies, Cake, Coffee)  0.001049           10.0
# 29                 (Soup, Sandwich, Cake)  0.001154           11.0
# 30                    (Cake, Muffin, Tea)  0.001259           12.0
# 31                   (Bread, Tiffin, Tea)  0.001259           12.0
# 32                  (Juice, Tea, Cookies)  0.001574           15.0
# 33                  (Spanish Brunch, Tea)  0.004617           44.0
# 34                        (Bakewell, Tea)  0.001259           12.0
# 35             (Cake, Hot chocolate, Tea)  0.001993           19.0
# 36                    (Tea, Cake, Pastry)  0.001259           12.0
# 37                    (Chicken Stew, Tea)  0.003148           30.0
# 38                   (Bread, Juice, Cake)  0.001784           17.0
# 39                     (Soup, Bread, Tea)  0.001574           15.0
# 40              (Sandwich, Coffee, Salad)  0.001574           15.0
# 41                           (Scone, Tea)  0.008289           79.0
# 42          (Cake, Hot chocolate, Coffee)  0.006820           65.0
# 43                 (Jammie Dodgers, Cake)  0.003043           29.0
# 44              (Sandwich, Mineral water)  0.003253           31.0
# 45                 (Vegan mincepie, Cake)  0.001259           12.0
# 46                            (Cake, Tea)  0.023607          225.0
# 47          (Sandwich, Tea, Cake, Coffee)  0.001049           10.0
# 48           (Jammie Dodgers, Bread, Tea)  0.001049           10.0
# 49               (Soup, Sandwich, Coffee)  0.003567           34.0
# 50                          (Tiffin, Tea)  0.003462           33.0
# 51                        (Tea, Frittata)  0.001889           18.0
# 52  (Hearty & Seasonal, Sandwich, Coffee)  0.001259           12.0
# 53                  (Smoothies, Sandwich)  0.001784           17.0
# 54                  (Sandwich, Cake, Tea)  0.001469           14.0
# 55        (Jammie Dodgers, Juice, Coffee)  0.001364           13.0
# 56                     (Juice, Cake, Tea)  0.001469           14.0
# 57       (Sandwich, Chicken Stew, Coffee)  0.001049           10.0
# 58                    (Tea, Cake, Coffee)  0.009967           95.0
#
#                      items_base        items_add  confidence       lift
# 0               (Toast, Pastry)         (Coffee)    0.866667   1.824249
# 1        (Vegan mincepie, Cake)         (Coffee)    0.833333   1.754086
# 2        (Extra Salami or Feta)         (Coffee)    0.815789   1.717158
# 3              (Scone, Cookies)         (Coffee)    0.789474   1.661765
# 4               (Juice, Pastry)         (Coffee)    0.772727   1.626516
# 5                 (Cake, Salad)         (Coffee)    0.769231   1.619156
# 6       (Spanish Brunch, Juice)         (Coffee)    0.730769   1.538198
# 7                 (Toast, Cake)         (Coffee)    0.714286   1.503502
# 8                        (Eggs)          (Bread)    0.500000   1.538747
# 9                 (Coke, Juice)       (Sandwich)    0.476190   6.674370
# 10         (Alfajores, Cookies)          (Juice)    0.434783  11.353186
# 11                 (Soup, Cake)            (Tea)    0.428571   3.025714
# 12       (Extra Salami or Feta)          (Salad)    0.421053  40.535885
# 13                (Scone, Cake)            (Tea)    0.377778   2.667111
# 14       (Extra Salami or Feta)  (Coffee, Salad)    0.368421  56.635823
# 15            (Medialuna, Cake)            (Tea)    0.342857   2.420571
# 16      (Jammie Dodgers, Bread)           (Cake)    0.340909   3.305396
# 17   (Alfajores, Hot chocolate)            (Tea)    0.323529   2.284118
# 18          (Alfajores, Pastry)            (Tea)    0.322581   2.277419
# 19               (Coke, Coffee)       (Sandwich)    0.311475   4.365694
# 20              (Cake, Brownie)            (Tea)    0.309524   2.185238
# 21                  (The Nomad)            (Tea)    0.293103   2.069310
# 22                   (Art Tray)            (Tea)    0.289474   2.043684
# 23             (Soup, Sandwich)            (Tea)    0.288462   2.036538
# 24           (Truffles, Coffee)       (Sandwich)    0.281690   3.948219
# 25                       (Coke)       (Sandwich)    0.266304   3.732569
# 26      (Coffee, Mineral water)       (Sandwich)    0.264151   3.702386
# 27                       (Soup)            (Tea)    0.263804   1.862454
# 28          (Smoothies, Coffee)           (Cake)    0.263158   2.551534
# 29                 (Soup, Cake)       (Sandwich)    0.261905   3.670903
# 30               (Cake, Muffin)            (Tea)    0.260870   1.841739
# 31              (Bread, Tiffin)            (Tea)    0.260870   1.841739
# 32             (Juice, Cookies)            (Tea)    0.258621   1.825862
# 33             (Spanish Brunch)            (Tea)    0.255814   1.806047
# 34                   (Bakewell)            (Tea)    0.250000   1.765000
# 35         (Hot chocolate, Tea)           (Cake)    0.250000   2.423957
# 36               (Cake, Pastry)            (Tea)    0.244898   1.728980
# 37               (Chicken Stew)            (Tea)    0.243902   1.721951
# 38               (Bread, Juice)           (Cake)    0.242857   2.354701
# 39                (Soup, Bread)            (Tea)    0.241935   1.708065
# 40              (Coffee, Salad)       (Sandwich)    0.241935   3.391010
# 41                      (Scone)            (Tea)    0.241590   1.705627
# 42      (Coffee, Hot chocolate)           (Cake)    0.232143   2.250817
# 43             (Jammie Dodgers)           (Cake)    0.232000   2.249432
# 44              (Mineral water)       (Sandwich)    0.231343   3.242548
# 45             (Vegan mincepie)           (Cake)    0.230769   2.237499
# 46                       (Cake)            (Tea)    0.228891   1.615972
# 47     (Sandwich, Cake, Coffee)            (Tea)    0.227273   1.604545
# 48      (Jammie Dodgers, Bread)            (Tea)    0.227273   1.604545
# 49               (Soup, Coffee)       (Sandwich)    0.226667   3.177000
# 50                     (Tiffin)            (Tea)    0.226027   1.595753
# 51                   (Frittata)            (Tea)    0.222222   1.568889
# 52  (Hearty & Seasonal, Coffee)       (Sandwich)    0.222222   3.114706
# 53                  (Smoothies)       (Sandwich)    0.220779   3.094481
# 54             (Sandwich, Cake)            (Tea)    0.215385   1.520615
# 55     (Jammie Dodgers, Coffee)          (Juice)    0.206349   5.388258
# 56                 (Juice, Tea)           (Cake)    0.205882   1.996200
# 57       (Chicken Stew, Coffee)       (Sandwich)    0.204082   2.860444
# 58                (Coffee, Tea)           (Cake)    0.201271   1.951491

# %% [markdown]
# The dataframe show itemsets that go together very often

# %% [markdown]
# **Input any item and suggest some items should by together**

# %% [markdown]
# Generating association rules with very small min_confidence.

# %%
full_association_rule = apyori.apriori(apyori_transactions, min_length=2, min_support=0.001, min_lift=1.01, min_confidence=0.05)
full_association_result = list(full_association_rule)

# %% [markdown]
# Save all rules in csv file.

# %%
all_rules_df = to_dataframe(full_association_result)
all_rules_df['items'] = all_rules_df.apply(lambda row: set(row['items']), axis=1)
all_rules_df['items_base'] = all_rules_df.apply(lambda row: set(row['items_base']), axis=1)
all_rules_df['items_add'] = all_rules_df.apply(lambda row: set(row['items_add']), axis=1)

all_rules_df.to_csv('rules.csv', index=False)

# %%
# build a function to recommendation
def recommended_items(item):
    _df = pd.read_csv('rules.csv')
    
    boolean = []
    for items in _df['items']:
        if item in items:
            boolean.append(True)
        else:
            boolean.append(False)

    filtered = pd.Series(boolean)
    _df = _df[filtered].reset_index(drop=True)
    return _df

# %% [markdown]
# If we want to recommend items that go with a specific item, we just need to put name of that item into recommended_items function. The function will give us a dataframe of association rules that includes our target item. These rules are sorted by confidence.

# %%
recommended_items('Bread').head() # just select the top (high confidence)
# Out:
#                          items   support  support_count          items_base  \
# 0            {'Bread', 'Eggs'}  0.001469           14.0            {'Eggs'}
# 1  {'Jammie Dodgers', 'Bread'}  0.004617           44.0  {'Jammie Dodgers'}
# 2        {'Bread', 'Focaccia'}  0.001993           19.0        {'Focaccia'}
# 3             {'Bread', 'Jam'}  0.005036           48.0             {'Jam'}
# 4     {'Soup', 'Bread', 'Tea'}  0.001574           15.0   {'Soup', 'Bread'}
#
#    items_add  confidence      lift
# 0  {'Bread'}    0.500000  1.538747
# 1  {'Bread'}    0.352000  1.083278
# 2  {'Bread'}    0.351852  1.082822
# 3  {'Bread'}    0.338028  1.040280
# 4    {'Tea'}    0.241935  1.708065

# %% [markdown]
# For example, we can recommend eggs, Jammie Dodgers, Focaccia, Jam, soup, tea to go with bread.
